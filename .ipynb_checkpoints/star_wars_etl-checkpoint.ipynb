# %% [markdown]
# <b>Import dependencies

# %%
import requests
import json
from pprint import pprint
import pymongo
from pymongo import MongoClient
import csv
import pandas as pd

# %% [markdown]
# <h2>Getting Star Wars Data From OMDB

# %% [markdown]
# <b>OMDB API url

# %%
url = "http://www.omdbapi.com/?i="
api_key = "&apikey=9fc25409"

# %% [markdown]
# <b>OMDB movie ids for the first three Star Wars films

# %%
movie_list = ['tt0076759','tt0080684','tt0086190']

# %%
# confirm url is working
response = requests.get(url + movie_list[0] + api_key)
print(response.url)
# Out:
# http://www.omdbapi.com/?i=tt0076759&apikey=9fc25409

# %% [markdown]
# <b>List with OMDB movie information in dictionaries

# %%
sw_data = []

for movie in movie_list:
    omdb_url = requests.get(url + movie + api_key)
    data = omdb_url.json()
    sw_data.append(data)

pprint(sw_data)
# Out:
# [{'Actors': 'Mark Hamill, Harrison Ford, Carrie Fisher, Peter Cushing',
#   'Awards': 'Won 6 Oscars. Another 50 wins & 28 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '21 Sep 2004',
#   'Director': 'George Lucas',
#   'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#   'Language': 'English',
#   'Metascore': '90',
#   'Plot': 'Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a '
#           "Wookiee and two droids to save the galaxy from the Empire's "
#           'world-destroying battle station, while also attempting to rescue '
#           'Princess Leia from the mysterious Darth Vader.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNzVlY2MwMjktM2E4OS00Y2Y3LWE3ZjctYzhkZGM3YzA1ZWM2XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SX300.jpg',
#   'Production': '20th Century Fox',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.6/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '93%'},
#               {'Source': 'Metacritic', 'Value': '90/100'}],
#   'Released': '25 May 1977',
#   'Response': 'True',
#   'Runtime': '121 min',
#   'Title': 'Star Wars: Episode IV - A New Hope',
#   'Type': 'movie',
#   'Website': 'http://www.starwars.com/episode-iv/',
#   'Writer': 'George Lucas',
#   'Year': '1977',
#   'imdbID': 'tt0076759',
#   'imdbRating': '8.6',
#   'imdbVotes': '1,133,583'},
#  {'Actors': 'Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams',
#   'Awards': 'Won 1 Oscar. Another 21 wins & 19 nominations.',
#   'BoxOffice': '$4,548,170',
#   'Country': 'USA',
#   'DVD': '21 Sep 2004',
#   'Director': 'Irvin Kershner',
#   'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#   'Language': 'English',
#   'Metascore': '82',
#   'Plot': 'After the Rebels are brutally overpowered by the Empire on the ice '
#           'planet Hoth, Luke Skywalker begins Jedi training with Yoda, while '
#           'his friends are pursued by Darth Vader.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SX300.jpg',
#   'Production': 'Twentieth Century Fox',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.7/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '95%'},
#               {'Source': 'Metacritic', 'Value': '82/100'}],
#   'Released': '20 Jun 1980',
#   'Response': 'True',
#   'Runtime': '124 min',
#   'Title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'Type': 'movie',
#   'Website': 'http://www.starwars.com/episode-v/',
#   'Writer': 'Leigh Brackett (screenplay by), Lawrence Kasdan (screenplay by), '
#             'George Lucas (story by)',
#   'Year': '1980',
#   'imdbID': 'tt0080684',
#   'imdbRating': '8.7',
#   'imdbVotes': '1,065,458'},
#  {'Actors': 'Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams',
#   'Awards': 'Nominated for 4 Oscars. Another 20 wins & 16 nominations.',
#   'BoxOffice': 'N/A',
#   'Country': 'USA',
#   'DVD': '12 Sep 2006',
#   'Director': 'Richard Marquand',
#   'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#   'Language': 'English',
#   'Metascore': '58',
#   'Plot': 'After a daring mission to rescue Han Solo from Jabba the Hutt, the '
#           'Rebels dispatch to Endor to destroy the second Death Star. '
#           'Meanwhile, Luke struggles to help Darth Vader back from the dark '
#           "side without falling into the Emperor's trap.",
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BOWZlMjFiYzgtMTUzNC00Y2IzLTk1NTMtZmNhMTczNTk0ODk1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#   'Production': 'Twentieth Century Fox',
#   'Rated': 'PG',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.3/10'},
#               {'Source': 'Rotten Tomatoes', 'Value': '81%'},
#               {'Source': 'Metacritic', 'Value': '58/100'}],
#   'Released': '25 May 1983',
#   'Response': 'True',
#   'Runtime': '131 min',
#   'Title': 'Star Wars: Episode VI - Return of the Jedi',
#   'Type': 'movie',
#   'Website': 'http://www.starwars.com/episode-vi/',
#   'Writer': 'Lawrence Kasdan (screenplay by), George Lucas (screenplay by), '
#             'George Lucas (story by)',
#   'Year': '1983',
#   'imdbID': 'tt0086190',
#   'imdbRating': '8.3',
#   'imdbVotes': '872,290'}]

# %% [markdown]
# <h2>Get sctipt from .txt file to dataframe

# %%
epiIV = pd.read_csv("SW_EpisodeIV.txt", escapechar='\\', skiprows=0, delimiter=" ", header=0, \
                names=['Key', 'Character', 'Dialog'], )
epiIV_df = pd.DataFrame(epiIV)
movie = sw_data[0]['Title']
epiIV_df['Movie'] = movie 
epiIV_df.head()
ordered_epiIV = epiIV_df[['Movie', 'Key', 'Character', 'Dialog']]
ordered_epiIV.head()
# Out:
#                                 Movie  Key Character  \
# 0  Star Wars: Episode IV - A New Hope    1  THREEPIO
# 1  Star Wars: Episode IV - A New Hope    2  THREEPIO
# 2  Star Wars: Episode IV - A New Hope    3  THREEPIO
# 3  Star Wars: Episode IV - A New Hope    4  THREEPIO
# 4  Star Wars: Episode IV - A New Hope    5  THREEPIO
#
#                                               Dialog
# 0  Did you hear that?  They've shut down the main...
# 1                                      We're doomed!
# 2  There'll be no escape for the Princess this time.
# 3                                       What's that?
# 4  I should have known better than to trust the l...

# %%
epiV = pd.read_csv("SW_EpisodeV.txt", escapechar='\\', skiprows=0, delimiter=" ", header=0, \
                names=['Key', 'Character', 'Dialog'], )
epiV_df = pd.DataFrame(epiV)
movie = sw_data[1]['Title']
epiV_df['Movie'] = movie 
ordered_epiV = epiV_df[['Movie', 'Key', 'Character', 'Dialog']]
ordered_epiV.head()
# Out:
#                                             Movie  Key Character  \
# 0  Star Wars: Episode V - The Empire Strikes Back    1      LUKE
# 1  Star Wars: Episode V - The Empire Strikes Back    2       HAN
# 2  Star Wars: Episode V - The Empire Strikes Back    3      LUKE
# 3  Star Wars: Episode V - The Empire Strikes Back    4       HAN
# 4  Star Wars: Episode V - The Empire Strikes Back    5      LUKE
#
#                                               Dialog
# 0  Echo Three to Echo Seven. Han, old buddy, do y...
# 1                    Loud and clear, kid. What's up?
# 2  Well, I finished my circle. I don't pick up an...
# 3  There isn't enough life on this ice cube to fi...
# 4  Right. I'll see you shortly. There's a meteori...

# %%
epiVI = pd.read_csv("SW_EpisodeVI.txt", escapechar='\\', skiprows=0, delimiter=" ", header=0, \
                names=['Key', 'Character', 'Dialog'], )
epiVI_df = pd.DataFrame(epiV)
movie = sw_data[2]['Title']
epiVI_df['Movie'] = movie 
ordered_epiVI = epiVI_df[['Movie', 'Key', 'Character', 'Dialog']]
ordered_epiVI.head()
# Out:
#                                         Movie  Key Character  \
# 0  Star Wars: Episode VI - Return of the Jedi    1      LUKE
# 1  Star Wars: Episode VI - Return of the Jedi    2       HAN
# 2  Star Wars: Episode VI - Return of the Jedi    3      LUKE
# 3  Star Wars: Episode VI - Return of the Jedi    4       HAN
# 4  Star Wars: Episode VI - Return of the Jedi    5      LUKE
#
#                                               Dialog
# 0  Echo Three to Echo Seven. Han, old buddy, do y...
# 1                    Loud and clear, kid. What's up?
# 2  Well, I finished my circle. I don't pick up an...
# 829  Star Wars: Episode VI - Return of the Jedi  830          THREEPIO
# 830  Star Wars: Episode VI - Return of the Jedi  831          THREEPIO
# 831  Star Wars: Episode VI - Return of the Jedi  832             LANDO
# 832  Star Wars: Episode VI - Return of the Jedi  833              LUKE
# 833  Star Wars: Episode VI - Return of the Jedi  834             LANDO
# 834  Star Wars: Episode VI - Return of the Jedi  835              LUKE
# 835  Star Wars: Episode VI - Return of the Jedi  836             LANDO
# 836  Star Wars: Episode VI - Return of the Jedi  837              LUKE
# 837  Star Wars: Episode VI - Return of the Jedi  838              LUKE
# 838  Star Wars: Episode VI - Return of the Jedi  839              LUKE
#
#                                                 Dialog
# 0    Did you hear that?  They've shut down the main...
# 1                                        We're doomed!
# 2    There'll be no escape for the Princess this time.
# 3                                         What's that?
# 4    I should have known better than to trust the l...
# 5    Hurry up!  Come with me!  What are you waiting...
# 6                   Artoo! Artoo-Detoo, where are you?
# 7                       At last!  Where have you been?
# 8    They're heading in this direction. What are we...
# 9                  Wait a minute, where are you going?
# 10   The Death Star plans are not in the main compu...
# 11      Where are those transmissions you intercepted?
# 12   We intercepted no transmissions. Aaah...  This...
# 13   If this is a consular ship... where is the Amb...
# 14   Commander, tear this ship apart until you've f...
# 15                         There she is! Set for stun!
# 16   She'll be all right. Inform Lord Vader we have...
# 17   Hey, you're not permitted in there.  It's rest...
# 18   Don't call me a mindless philosopher, you over...
# 19   Secret mission?  What plans?  What are you tal...
# 20                           I'm going to regret this.
# 21                             There goes another one.
# 22   Hold your fire.  There are no life forms.  It ...
# 23   That's funny, the damage doesn't look as bad f...
# 24                      Are you sure this things safe?
# 25                    I've told you kids to slow down!
# 26        Did I hear a young noise blast through here?
# 27              It was just Wormie on another rampage.
# 28                    Shape it up you guys!...  Biggs?
# 29   I didn't know you were back!  When did you get...
# ..                                                 ...
# 809    All the coordinates are set. It's now or never.
# 810                                          Punch it!
# 811  They told me they fixed it. I trusted them to ...
# 812  They'll be in range of our tractor beam in mom...
# 813  Did your men deactivate the hyperdrive on the ...
# 814                                      Yes, my lord.
# 815  Good. Prepare the boarding party and set for y...
# 816                                      Yes, my lord.
# 817  Noisy brute. Why don't we just go into light-s...
# 818  We can't? How would you know the hyperdrive is...
# 819  The city's central computer told you? Artoo-De...
# 820                                              Luke.
# 821                                            Father.
# 822                                 Son, come with me.
# 823                       Ben, why didn't you tell me?
# 824                                            Chewie!
# 825                                        It's Vader.
# 826                         Luke...it is your destiny.
# 827                       Ben, why didn't you tell me?
# 828    Alert all commands. Ready for the tractor beam.
# 829  Artoo, come back at once! You haven't finished...
# 830                                    Oh, you did it!
# 831                     Luke, we're ready for takeoff.
# 832                                   Good luck, Lando
# 833  When we find Jabba the Hut and that bounty  hu...
# 834  I'll meet you at the rendezvous point on  Tato...
# 835               Princess, we'll find Han. I promise.
# 836           Chewie, I'll be waiting for your signal.
# 837     Take care, you two. May the Force be with you.
# 838                                                Ow!
#
# [2688 rows x 4 columns]

# %%
script_list = combined_movies.to_dict('records')

# %% [markdown]
# <h2>Connection to Mongodb

# %%
client = MongoClient('mongodb://localhost:27017/')

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.star_wars

# %%
db.omdb_info.drop()
db.sw_script.drop()

# %%
collection_omdb = db.omdb_info

# %%
result = collection_omdb.insert_many(sw_data)

# %%
collection_scripts = db.sw_script

# %%
result = collection_scripts.insert_many(script_list)

# %%
db.list_collection_names()
# Out:
# ['omdb_info', 'sw_script']
