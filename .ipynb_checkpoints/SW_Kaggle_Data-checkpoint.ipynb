# %%
import pandas as pd
import csv

# %%
epiIV = pd.read_csv("SW_EpisodeIV.txt", escapechar='\\', skiprows=0, delimiter=" ", header=0, \
                names=['Key', 'Character', 'Dialog'], )
epiIV_df = pd.DataFrame(epiIV)
movie = "Episode IV"
epiIV_df['Movie'] = movie 
epiIV_df.head()
ordered_epiIV = epiIV_df[['Movie', 'Key', 'Character', 'Dialog']]
ordered_epiIV.head()
# Out:
#         Movie  Key Character  \
# 0  Episode IV    1  THREEPIO
# 1  Episode IV    2  THREEPIO
# 2  Episode IV    3  THREEPIO
# 3  Episode IV    4  THREEPIO
# 4  Episode IV    5  THREEPIO
#
#                                               Dialog
# 0  Did you hear that?  They've shut down the main...
# 1                                      We're doomed!
# 2  There'll be no escape for the Princess this time.
# 3                                       What's that?
# 4  I should have known better than to trust the l...

# %%
epiV = pd.read_csv("SW_EpisodeV.txt", escapechar='\\', skiprows=0, delimiter=" ", header=0, \
                names=['Key', 'Character', 'Dialog'], )
epiV_df = pd.DataFrame(epiV)
movie = "Episode V"
epiV_df['Movie'] = movie 
ordered_epiV = epiV_df[['Movie', 'Key', 'Character', 'Dialog']]
ordered_epiV.head()
# Out:
#        Movie  Key Character                                             Dialog
# 0  Episode V    1      LUKE  Echo Three to Echo Seven. Han, old buddy, do y...
# 1  Episode V    2       HAN                    Loud and clear, kid. What's up?
# 2  Episode V    3      LUKE  Well, I finished my circle. I don't pick up an...
# 3  Episode V    4       HAN  There isn't enough life on this ice cube to fi...
# 4  Episode V    5      LUKE  Right. I'll see you shortly. There's a meteori...

# %%
epiVI = pd.read_csv("SW_EpisodeVI.txt", escapechar='\\', skiprows=0, delimiter=" ", header=0, \
                names=['Key', 'Character', 'Dialog'], )
epiVI_df = pd.DataFrame(epiV)
movie = "Episode VI"
epiVI_df['Movie'] = movie 
ordered_epiVI = epiVI_df[['Movie', 'Key', 'Character', 'Dialog']]
ordered_epiVI.head()
# Out:
#         Movie  Key Character  \
# 0  Episode VI    1      LUKE
# 1  Episode VI    2       HAN
# 2  Episode VI    3      LUKE
# 3  Episode VI    4       HAN
# 4  Episode VI    5      LUKE
#
#                                               Dialog
# 0  Echo Three to Echo Seven. Han, old buddy, do y...
# 1                    Loud and clear, kid. What's up?
# 2  Well, I finished my circle. I don't pick up an...
# 3  There isn't enough life on this ice cube to fi...
# 4  Right. I'll see you shortly. There's a meteori...

# %%
frames = [ordered_epiIV, ordered_epiV, ordered_epiVI]
combined_movies = pd.concat(frames)
combined_movies
# Out:
#           Movie  Key         Character  \
# 0    Episode IV    1          THREEPIO
# 1    Episode IV    2          THREEPIO
# 2    Episode IV    3          THREEPIO
# 3    Episode IV    4          THREEPIO
# 4    Episode IV    5          THREEPIO
# 5    Episode IV    6              LUKE
# 6    Episode IV    7          THREEPIO
# 7    Episode IV    8          THREEPIO
# 8    Episode IV    9          THREEPIO
# 9    Episode IV   10          THREEPIO
# 10   Episode IV   11  IMPERIAL OFFICER
# 11   Episode IV   12             VADER
# 12   Episode IV   13     REBEL OFFICER
# 13   Episode IV   14             VADER
# 14   Episode IV   15             VADER
# 15   Episode IV   16           TROOPER
# 16   Episode IV   17           TROOPER
# 17   Episode IV   18          THREEPIO
# 18   Episode IV   19          THREEPIO
# 19   Episode IV   20          THREEPIO
# 20   Episode IV   21          THREEPIO
# 21   Episode IV   22       CHIEF PILOT
# 22   Episode IV   23           CAPTAIN
# 23   Episode IV   24          THREEPIO
# 24   Episode IV   25          THREEPIO
# 25   Episode IV   26             WOMAN
# 26   Episode IV   27             FIXER
# 27   Episode IV   28             CAMIE
# 28   Episode IV   29              LUKE
# 29   Episode IV   30              LUKE
# ..          ...  ...               ...
# 809  Episode VI  810              LEIA
# 810  Episode VI  811             LANDO
# 811  Episode VI  812             LANDO
# 812  Episode VI  813             PIETT
# 813  Episode VI  814             VADER
# 814  Episode VI  815             PIETT
# 815  Episode VI  816             VADER
# 816  Episode VI  817             PIETT
# 817  Episode VI  818          THREEPIO
# 818  Episode VI  819          THREEPIO
# 819  Episode VI  820          THREEPIO
# 820  Episode VI  821             VADER
# 821  Episode VI  822              LUKE
# 822  Episode VI  823             VADER
# 823  Episode VI  824              LUKE
# 824  Episode VI  825             LANDO
# 825  Episode VI  826              LUKE
# 826  Episode VI  827             VADER
# 827  Episode VI  828              LUKE
# 828  Episode VI  829             PIETT
# 829  Episode VI  830          THREEPIO
# 830  Episode VI  831          THREEPIO
# 831  Episode VI  832             LANDO
# 832  Episode VI  833              LUKE
# 833  Episode VI  834             LANDO
# 834  Episode VI  835              LUKE
# 835  Episode VI  836             LANDO
# 836  Episode VI  837              LUKE
# 837  Episode VI  838              LUKE
# 838  Episode VI  839              LUKE
#
#                                                 Dialog
# 0    Did you hear that?  They've shut down the main...
# 1                                        We're doomed!
# 2    There'll be no escape for the Princess this time.
# 3                                         What's that?
# 4    I should have known better than to trust the l...
# 5    Hurry up!  Come with me!  What are you waiting...
# 6                   Artoo! Artoo-Detoo, where are you?
# 7                       At last!  Where have you been?
# 8    They're heading in this direction. What are we...
# 9                  Wait a minute, where are you going?
# 10   The Death Star plans are not in the main compu...
# 11      Where are those transmissions you intercepted?
# 12   We intercepted no transmissions. Aaah...  This...
# 13   If this is a consular ship... where is the Amb...
# 14   Commander, tear this ship apart until you've f...
# 15                         There she is! Set for stun!
# 16   She'll be all right. Inform Lord Vader we have...
# 17   Hey, you're not permitted in there.  It's rest...
# 18   Don't call me a mindless philosopher, you over...
# 19   Secret mission?  What plans?  What are you tal...
# 20                           I'm going to regret this.
# 21                             There goes another one.
# 22   Hold your fire.  There are no life forms.  It ...
# 23   That's funny, the damage doesn't look as bad f...
# 24                      Are you sure this things safe?
# 25                    I've told you kids to slow down!
# 26        Did I hear a young noise blast through here?
# 27              It was just Wormie on another rampage.
# 28                    Shape it up you guys!...  Biggs?
# 29   I didn't know you were back!  When did you get...
# ..                                                 ...
# 809    All the coordinates are set. It's now or never.
# 810                                          Punch it!
# 811  They told me they fixed it. I trusted them to ...
# 812  They'll be in range of our tractor beam in mom...
# 813  Did your men deactivate the hyperdrive on the ...
# 814                                      Yes, my lord.
# 815  Good. Prepare the boarding party and set for y...
# 816                                      Yes, my lord.
# 817  Noisy brute. Why don't we just go into light-s...
# 818  We can't? How would you know the hyperdrive is...
# 819  The city's central computer told you? Artoo-De...
# 820                                              Luke.
# 821                                            Father.
# 822                                 Son, come with me.
# 823                       Ben, why didn't you tell me?
# 824                                            Chewie!
# 825                                        It's Vader.
# 826                         Luke...it is your destiny.
# 827                       Ben, why didn't you tell me?
# 828    Alert all commands. Ready for the tractor beam.
# 829  Artoo, come back at once! You haven't finished...
# 830                                    Oh, you did it!
# 831                     Luke, we're ready for takeoff.
# 832                                   Good luck, Lando
# 833  When we find Jabba the Hut and that bounty  hu...
# 834  I'll meet you at the rendezvous point on  Tato...
# 835               Princess, we'll find Han. I promise.
# 836           Chewie, I'll be waiting for your signal.
# 837     Take care, you two. May the Force be with you.
# 838                                                Ow!
#
# [2688 rows x 4 columns]

# %%
combined_movies.to_dict('records')
# Out:
# [{'Movie': 'Episode IV',
#   'Key': 1,
#   'Character': 'THREEPIO',
#   'Dialog': "Did you hear that?  They've shut down the main reactor.  We'll be destroyed for sure.  This is madness!"},
#  {'Movie': 'Episode IV',
#   'Key': 2,
#   'Character': 'THREEPIO',
#   'Dialog': "We're doomed!"},
#  {'Movie': 'Episode IV',
#   'Key': 3,
#   'Character': 'THREEPIO',
#   'Dialog': "There'll be no escape for the Princess this time."},
#  {'Movie': 'Episode IV',
#   'Key': 4,
#   'Character': 'THREEPIO',
#   'Dialog': "What's that?"},
#  {'Movie': 'Episode IV',
#   'Key': 5,
#   'Character': 'THREEPIO',
#   'Dialog': 'I should have known better than to trust the logic of a half-sized thermocapsulary dehousing assister...'},
#  {'Movie': 'Episode IV',
#   'Key': 6,
#   'Character': 'LUKE',
#   'Dialog': 'Hurry up!  Come with me!  What are you waiting for?!  Get in gear!'},
#  {'Movie': 'Episode IV',
#   'Key': 7,
#   'Character': 'THREEPIO',
#   'Dialog': 'Artoo! Artoo-Detoo, where are you?'},
#  {'Movie': 'Episode IV',
#   'Key': 8,
#   'Character': 'THREEPIO',
#   'Dialog': 'At last!  Where have you been?'},
#  {'Movie': 'Episode IV',
#   'Key': 9,
#   'Character': 'THREEPIO',
#   'Dialog': "They're heading in this direction. What are we going to do?  We'll be sent to the spice mines of Kessel or smashed into who knows what!"},
#  {'Movie': 'Episode IV',
#   'Key': 10,
#   'Character': 'THREEPIO',
#   'Dialog': 'Wait a minute, where are you going?'},
#  {'Movie': 'Episode IV',
#   'Key': 11,
#   'Character': 'IMPERIAL OFFICER',
#   'Dialog': 'The Death Star plans are not in the main computer.'},
#  {'Movie': 'Episode IV',
#   'Key': 12,
#   'Character': 'VADER',
#   'Dialog': 'Where are those transmissions you intercepted?'},
#  {'Movie': 'Episode IV',
#   'Key': 13,
#   'Character': 'REBEL OFFICER',
#   'Dialog': 'We intercepted no transmissions. Aaah...  This is a consular ship. Were on a diplomatic mission.'},
#  {'Movie': 'Episode IV',
#   'Key': 14,
#   'Character': 'VADER',
#   'Dialog': 'If this is a consular ship... where is the Ambassador?'},
#  {'Movie': 'Episode IV',
#   'Key': 15,
#   'Character': 'VADER',
#   'Dialog': "Commander, tear this ship apart until you've found those plans and bring me the Ambassador.  I want her alive!"},
#  {'Movie': 'Episode IV',
#   'Key': 16,
#   'Character': 'TROOPER',
#   'Dialog': 'There she is! Set for stun!'},
#  {'Movie': 'Episode IV',
#   'Key': 17,
#   'Character': 'TROOPER',
#   'Dialog': "She'll be all right. Inform Lord Vader we have a prisoner."},
#  {'Movie': 'Episode IV',
#   'Key': 18,
#   'Character': 'THREEPIO',
#   'Dialog': "Hey, you're not permitted in there.  It's restricted. You'll be deactivated for sure.."},
#  {'Movie': 'Episode IV',
#   'Key': 19,
#   'Character': 'THREEPIO',
#   'Dialog': "Don't call me a mindless philosopher, you overweight glob of grease!  Now come out before somebody sees you."},
#  {'Movie': 'Episode IV',
#   'Key': 20,
#   'Character': 'THREEPIO',
#   'Dialog': "Secret mission?  What plans?  What are you talking about?  I'm not getting in there!"},
#  {'Movie': 'Episode IV',
#   'Key': 21,
#   'Character': 'THREEPIO',
#   'Dialog': "I'm going to regret this."},
#  {'Movie': 'Episode IV',
#   'Key': 22,
#   'Character': 'CHIEF PILOT',
#   'Dialog': 'There goes another one.'},
#  {'Movie': 'Episode IV',
#   'Key': 23,
#   'Character': 'CAPTAIN',
#   'Dialog': 'Hold your fire.  There are no life forms.  It must have been short-circuited.'},
#  {'Movie': 'Episode IV',
#   'Key': 24,
#   'Character': 'THREEPIO',
#   'Dialog': "That's funny, the damage doesn't look as bad from out here."},
#  {'Movie': 'Episode IV',
#   'Key': 25,
#   'Character': 'THREEPIO',
#   'Dialog': 'Are you sure this things safe?'},
#  {'Movie': 'Episode IV',
#   'Key': 26,
#   'Character': 'WOMAN',
#   'Dialog': "I've told you kids to slow down!"},
#  {'Movie': 'Episode IV',
#   'Key': 27,
#   'Character': 'FIXER',
#   'Dialog': 'Did I hear a young noise blast through here?'},
#  {'Movie': 'Episode IV',
#   'Key': 28,
#   'Character': 'CAMIE',
#   'Dialog': 'It was just Wormie on another rampage.'},
#  {'Movie': 'Episode IV',
#   'Key': 29,
#   'Character': 'LUKE',
#   'Dialog': 'Shape it up you guys!...  Biggs?'},
#  {'Movie': 'Episode IV',
#   'Key': 30,
#   'Character': 'LUKE',
#   'Dialog': "I didn't know you were back!  When did you get in?"},
#  {'Movie': 'Episode IV',
#   'Key': 31,
#   'Character': 'BIGGS',
#   'Dialog': "Just now.  I wanted to surprise you, hot shot.  I thought you'd be here... certainly didn't expect you to be out working. "},
#  {'Movie': 'Episode IV',
#   'Key': 32,
#   'Character': 'LUKE',
#   'Dialog': "The Academy didn't change you much... but you're back so soon?  Hey, what happened, didn't you get your commission?"},
#  {'Movie': 'Episode IV',
#   'Key': 33,
#   'Character': 'BIGGS',
#   'Dialog': 'Of course I got it.  Signed aboard The Rand Ecliptic last week.  First mate Biggs Darklighter at your service...... I just came back to say goodbye to all you unfortunate landlocked simpletons.'},
#  {'Movie': 'Episode IV',
#   'Key': 34,
#   'Character': 'LUKE',
#   'Dialog': "I almost forgot.  There's a battle going on!  Right here in our system.  Come and look!"},
#  {'Movie': 'Episode IV',
#   'Key': 35,
#   'Character': 'DEAK',
#   'Dialog': 'Not again!  Forget it.'},
#  {'Movie': 'Episode IV',
#   'Key': 36,
#   'Character': 'LUKE',
#   'Dialog': 'There they are!'},
#  {'Movie': 'Episode IV',
#   'Key': 37,
#   'Character': 'BIGGS',
#   'Dialog': "That's no battle, hot shot... they're just sitting there!  Probably a freighter-tanker refueling."},
#  {'Movie': 'Episode IV',
#   'Key': 38,
#   'Character': 'LUKE',
#   'Dialog': 'But there was a lot of firing earlier...'},
#  {'Movie': 'Episode IV',
#   'Key': 39,
#   'Character': 'LUKE',
#   'Dialog': 'Hey, easy with those...'},
#  {'Movie': 'Episode IV',
#   'Key': 40,
#   'Character': 'CAMIE',
#   'Dialog': "Don't worry about it, Wormie."},
#  {'Movie': 'Episode IV',
#   'Key': 41,
#   'Character': 'FIXER',
#   'Dialog': 'I keep telling you, the Rebellion is a long way from here.  I doubt if the Empire would even fight to keep this system.  Believe me Luke, this planet is a big hunk of nothing...'},
#  {'Movie': 'Episode IV',
#   'Key': 42,
#   'Character': 'LEIA',
#   'Dialog': "Lord Vader, I should have known.  Only you could be so bold.  The Imperial Senate will not sit stillfor this, when they hear you've attacked a diplomatic..."},
#  {'Movie': 'Episode IV',
#   'Key': 43,
#   'Character': 'VADER',
#   'Dialog': "Don't play games with me, Your Highness.  You weren't on any mercy mission this time.  You passed directly through a restricted system.  Several transmissions were beamed to this ship by Rebel spies.  I want to know what happened to the plans they sent you."},
#  {'Movie': 'Episode IV',
#   'Key': 44,
#   'Character': 'LEIA',
#   'Dialog': "I don't know what you're talking about.  I'm a member of the Imperial Senate on a diplomatic mission to Alderaan..."},
#  {'Movie': 'Episode IV',
#   'Key': 45,
#   'Character': 'VADER',
#   'Dialog': "You're a part of the Rebel Alliance... and a traitor.  Take her away!"},
#  {'Movie': 'Episode IV',
#   'Key': 46,
#   'Character': 'COMMANDER',
#   'Dialog': 'Holding her is dangerous.  If word of this gets out, it could generate sympathy for the Rebellion in the senate.'},
#  {'Movie': 'Episode IV',
#   'Key': 47,
#   'Character': 'VADER',
#   'Dialog': 'I have traced the Rebel spies to her.  Now she is my only link to find their secret base!'},
#  {'Movie': 'Episode IV',
#   'Key': 48,
#   'Character': 'COMMANDER',
#   'Dialog': 'you anything.'},
#  {'Movie': 'Episode IV',
#   'Key': 49,
#   'Character': 'VADER',
#   'Dialog': 'Leave that to me.  Send a distress signal and then inform the senate that all aboard were killed!'},
#  {'Movie': 'Episode IV',
#   'Key': 50,
#   'Character': 'SECOND OFFICER',
#   'Dialog': 'Lord Vader, the battle station plans are not aboard this ship!  And no transmissions were made.  An escape pod was jettisoned during the fighting, but no life forms were aboard.'},
#  {'Movie': 'Episode IV',
#   'Key': 51,
#   'Character': 'VADER',
#   'Dialog': "She must have hidden the plans in the escape pod.  Send a detachment down to retrieve them.  See to it personally, Commander.  There'll be no one to stop us this time."},
#  {'Movie': 'Episode IV',
#   'Key': 52,
#   'Character': 'COMMANDER',
#   'Dialog': 'Yes, sir.'},
#  {'Movie': 'Episode IV',
#   'Key': 53,
#   'Character': 'THREEPIO',
#   'Dialog': "How did I get into this mess?  I really don't know how.  We seem to be made to suffer.  It's our lot in life."},
#  {'Movie': 'Episode IV',
#   'Key': 54,
#   'Character': 'THREEPIO',
#   'Dialog': "I've got to rest before I fall apart.  My joints are almost frozen. "},
#  {'Movie': 'Episode IV',
#   'Key': 55,
#   'Character': 'THREEPIO',
#   'Dialog': 'What a desolate place this is.'},
#  {'Movie': 'Episode IV',
#   'Key': 56,
#   'Character': 'THREEPIO',
#   'Dialog': 'Where are you going?'},
#  {'Movie': 'Episode IV',
#   'Key': 57,
#   'Character': 'THREEPIO',
#   'Dialog': "Well, I'm not going that way.  It's much too rocky.  This way is much easier."},
#  {'Movie': 'Episode IV',
#   'Key': 58,
#   'Character': 'THREEPIO',
#   'Dialog': 'What makes you think there are settlements over there?'},
#  {'Movie': 'Episode IV',
#   'Key': 59,
#   'Character': 'THREEPIO',
#   'Dialog': "Don't get technical with me."},
#  {'Movie': 'Episode IV',
#   'Key': 60,
#   'Character': 'THREEPIO',
#   'Dialog': "What mission?  What are you talking about?  I've had just about enough of you!  Go that way!  You'll be malfunctioning within a day, you nearsighted scrap pile!"},
#  {'Movie': 'Episode IV',
#   'Key': 61,
#   'Character': 'THREEPIO',
#   'Dialog': "And don't let me catch you following me begging for help, because you won't get it."},
#  {'Movie': 'Episode IV',
#   'Key': 62,
#   'Character': 'THREEPIO',
#   'Dialog': "No more adventures.  I'm not going that way."},
#  {'Movie': 'Episode IV',
#   'Key': 63,
#   'Character': 'THREEPIO',
#   'Dialog': "That malfunctioning little twerp.  This is all his fault!  He tricked me into going this way, but he'll do no better."},
#  {'Movie': 'Episode IV',
#   'Key': 64,
#   'Character': 'THREEPIO',
#   'Dialog': "Wait, what's that?  A transport!  I'm saved!"},
#  {'Movie': 'Episode IV',
#   'Key': 65,
#   'Character': 'THREEPIO',
#   'Dialog': 'Over here!  Help!  Please, help!'},
#  {'Movie': 'Episode IV',
#   'Key': 66,
#   'Character': 'LUKE',
#   'Dialog': "... so I cut off my power, shut down the afterburners and came in low on Deak's trail.  I was so close I thought I was going to fry my instruments. As it was I busted up the Skyhopper pretty bad.  Uncle Owen was pretty upset.  He grounded me for the rest of the season.  You should have been there... it was fantastic."},
#  {'Movie': 'Episode IV',
#   'Key': 67,
#   'Character': 'BIGGS',
#   'Dialog': "You ought to take it a little easy Luke.  You may be the hottest bushpilot this side of Mos Eisley, but those little Skyhoppers are dangerous.  Keep it up, and one day, whammo, you're going to be nothing more than a dark spot on the down side of a canyon wall."},
#  {'Movie': 'Episode IV',
#   'Key': 68,
#   'Character': 'LUKE',
#   'Dialog': "Look who's talking.  Now that you've been around those giant starships you're beginning to sound like my uncle. You've gotten soft in the city..."},
#  {'Movie': 'Episode IV',
#   'Key': 69,
#   'Character': 'BIGGS',
#   'Dialog': "I've missed you kid."},
#  {'Movie': 'Episode IV',
#   'Key': 70,
#   'Character': 'LUKE',
#   'Dialog': "Well, things haven't been the same since you left, Biggs.  It's been so...quiet."},
#  {'Movie': 'Episode IV',
#   'Key': 71,
#   'Character': 'BIGGS',
#   'Dialog': "Luke, I didn't come back just to say goodbye...  I shouldn't tell you this, but you're the only one I can trust... and if I don't come back, I want somebody to know."},
#  {'Movie': 'Episode IV',
#   'Key': 72,
#   'Character': 'LUKE',
#   'Dialog': 'What are you talking about?'},
#  {'Movie': 'Episode IV',
#   'Key': 73,
#   'Character': 'BIGGS',
#   'Dialog': "I made some friends at the Academy. ... when our frigate goes to one of the central systems, we're going to jump ship and join the Alliance..."},
#  {'Movie': 'Episode IV',
#   'Key': 74,
#   'Character': 'LUKE',
#   'Dialog': 'Join the Rebellion?!  Are you kidding!  How?'},
#  {'Movie': 'Episode IV',
#   'Key': 75,
#   'Character': 'BIGGS',
#   'Dialog': 'Quiet down will ya!  You got a mouth bigger than a meteor crater!'},
#  {'Movie': 'Episode IV',
#   'Key': 76,
#   'Character': 'LUKE',
#   'Dialog': "I'm sorry.  I'm quiet. Listen how quiet I am.  You can barely hear me..."},
#  {'Movie': 'Episode IV',
#   'Key': 77,
#   'Character': 'BIGGS',
#   'Dialog': 'My friend has a friend on Bestine who might help us make contact.'},
#  {'Movie': 'Episode IV',
#   'Key': 78,
#   'Character': 'LUKE',
#   'Dialog': 'around forever trying to find them.'},
#  {'Movie': 'Episode IV',
#   'Key': 79,
#   'Character': 'BIGGS',
#   'Dialog': "I know it's a long shot, but if I don't find them I'll do what I can on my own...  It's what we always talked about.  Luke, I'm not going to wait for the Empire to draft me into service.  The Rebellion is spreading and I want to be on the right side - the side I believe in. "},
#  {'Movie': 'Episode IV',
#   'Key': 80,
#   'Character': 'LUKE',
#   'Dialog': "And I'm stuck here..."},
#  {'Movie': 'Episode IV',
#   'Key': 81,
#   'Character': 'BIGGS',
#   'Dialog': "I thought you were going to the Academy next term.  You'll get your chance to get off this rock."},
#  {'Movie': 'Episode IV',
#   'Key': 82,
#   'Character': 'LUKE',
#   'Dialog': "Not likely!  I had to cancel my application.  There has been a lot of unrest among the Sand People since you left... they've even raided the outskirts of Anchorhead."},
#  {'Movie': 'Episode IV',
#   'Key': 83,
#   'Character': 'BIGGS',
#   'Dialog': 'Your uncle could hold off a whole colony of Sand People with one blaster.'},
#  {'Movie': 'Episode IV',
#   'Key': 84,
#   'Character': 'LUKE',
#   'Dialog': "I know, but he's got enough vaporators going to make the place pay off.  He needs me for just one more season.  I can't leave him now."},
#  {'Movie': 'Episode IV',
#   'Key': 85,
#   'Character': 'BIGGS',
#   'Dialog': "I feel for you, Luke, you're going to have to learn what seems to be important or what really is important.  What good is all your uncle's work if it's taken over by the Empire?...  You know they're starting to nationalize commerce in the central systems...it won't be long before your uncle is merely a tenant, slaving for the greater glory of the Empire."},
#  {'Movie': 'Episode IV',
#   'Key': 86,
#   'Character': 'LUKE',
#   'Dialog': "It couldn't happen here.  You said it yourself.  The Empire won't bother with this rock."},
#  {'Movie': 'Episode IV',
#   'Key': 87,
#   'Character': 'BIGGS',
#   'Dialog': 'Things always change.'},
#  {'Movie': 'Episode IV',
#   'Key': 88,
#   'Character': 'LUKE',
#   'Dialog': 'I wish I was going...  Are you going to be around long? '},
#  {'Movie': 'Episode IV',
#   'Key': 89,
#   'Character': 'BIGGS',
#   'Dialog': "No, I'm leaving in the morning..."},
#  {'Movie': 'Episode IV',
#   'Key': 90,
#   'Character': 'LUKE',
#   'Dialog': "Then I guess I won't see you."},
#  {'Movie': 'Episode IV',
#   'Key': 91,
#   'Character': 'BIGGS',
#   'Dialog': "Maybe someday...  I'll keep a lookout."},
#  {'Movie': 'Episode IV',
#   'Key': 92,
#   'Character': 'LUKE',
#   'Dialog': "Well, I'll be at the Academy next season... after that who knows.  I won't be drafted into the Imperial Starfleet that's for sure...  Take care of yourself, you'll always be the best friend I've got."},
#  {'Movie': 'Episode IV',
#   'Key': 93,
#   'Character': 'BIGGS',
#   'Dialog': 'So long, Luke.'},
#  {'Movie': 'Episode IV',
#   'Key': 94,
#   'Character': 'THREEPIO',
#   'Dialog': "Artoo-Detoo!  It's you!  It's you!"},
#  {'Movie': 'Episode IV',
#   'Key': 95,
#   'Character': 'FIRST TROOPER',
#   'Dialog': 'Someone was in the pod.  The tracks go off in this direction. '},
#  {'Movie': 'Episode IV',
#   'Key': 96,
#   'Character': 'SECOND TROOPER',
#   'Dialog': 'Look, sir - droids.'},
#  {'Movie': 'Episode IV',
#   'Key': 97,
#   'Character': 'THREEPIO',
#   'Dialog': 'Wake up!  Wake up!'},
#  {'Movie': 'Episode IV',
#   'Key': 98,
#   'Character': 'THREEPIO',
#   'Dialog': "We're doomed."},
#  {'Movie': 'Episode IV',
#   'Key': 99,
#   'Character': 'THREEPIO',
#   'Dialog': "Do you think they'll melt us down?"},
#  {'Movie': 'Episode IV',
#   'Key': 100,
#   'Character': 'THREEPIO',
#   'Dialog': "Don't shoot!  Don't shoot!  Will this never end?"},
#  {'Movie': 'Episode IV',
#   'Key': 101,
#   'Character': 'BERU',
#   'Dialog': 'Luke, tell Owen that if he gets a translator to be sure it speaks Bocce.'},
#  {'Movie': 'Episode IV',
#   'Key': 102,
#   'Character': 'LUKE',
#   'Dialog': "It looks like we don't have much of a choice but I'll remind him."},
#  {'Movie': 'Episode IV',
#   'Key': 103,
#   'Character': 'OWEN',
#   'Dialog': 'I have no need for a protocol droid.'},
#  {'Movie': 'Episode IV',
#   'Key': 104,
#   'Character': 'THREEPIO',
#   'Dialog': "Sir - not in an environment such as this - that's why I've also been programmed for over thirty secondary functions that..."},
#  {'Movie': 'Episode IV',
#   'Key': 105,
#   'Character': 'OWEN',
#   'Dialog': 'What I really need is a droid that understands the binary languages of moisture vaporators.'},
#  {'Movie': 'Episode IV',
#   'Key': 106,
#   'Character': 'THREEPIO',
#   'Dialog': 'Vaporators!  Sir - My first job was programming binary load lifters... very similar to your vaporators.  You could say...'},
#  {'Movie': 'Episode IV',
#   'Key': 107,
#   'Character': 'OWEN',
#   'Dialog': 'Do you speak Bocce?'},
#  {'Movie': 'Episode IV',
#   'Key': 108,
#   'Character': 'THREEPIO',
#   'Dialog': "Of course I can, sir.  It's like a second language for me...  I'm as fluent in Bocce..."},
#  {'Movie': 'Episode IV',
#   'Key': 109,
#   'Character': 'OWEN',
#   'Dialog': "All right; shut up! I'll take this one."},
#  {'Movie': 'Episode IV',
#   'Key': 110,
#   'Character': 'THREEPIO',
#   'Dialog': 'Shutting up, sir.'},
#  {'Movie': 'Episode IV',
#   'Key': 111,
#   'Character': 'OWEN',
#   'Dialog': 'Luke, take these two over to the garage, will you?  I want you to have both of them cleaned up before dinner.'},
#  {'Movie': 'Episode IV',
#   'Key': 112,
#   'Character': 'LUKE',
#   'Dialog': 'But I was going into Toshi Station to pick up some power converters...'},
#  {'Movie': 'Episode IV',
#   'Key': 113,
#   'Character': 'OWEN',
#   'Dialog': 'You can waste time with your friends when your chores are done.  Now, come on, get to it!'},
#  {'Movie': 'Episode IV',
#   'Key': 114,
#   'Character': 'LUKE',
#   'Dialog': "All right, come on!  And the red one, come on.  Well, come on, Red, let's go."},
#  {'Movie': 'Episode IV',
#   'Key': 115,
#   'Character': 'LUKE',
#   'Dialog': 'Uncle Owen...'},
#  {'Movie': 'Episode IV', 'Key': 116, 'Character': 'OWEN', 'Dialog': 'Yeah?'},
#  {'Movie': 'Episode IV',
#   'Key': 117,
#   'Character': 'LUKE',
#   'Dialog': 'This R2 unit has a bad motivator.  Look!'},
#  {'Movie': 'Episode IV',
#   'Key': 118,
#   'Character': 'OWEN',
#   'Dialog': "Hey, what're you trying to push on us?"},
#  {'Movie': 'Episode IV',
#   'Key': 119,
#   'Character': 'THREEPIO',
#   'Dialog': 'Excuse me, sir, but that R2 unit is in prime condition.  A real bargain.'},
#  {'Movie': 'Episode IV',
#   'Key': 120,
#   'Character': 'LUKE',
#   'Dialog': 'Uncle Owen...'},
#  {'Movie': 'Episode IV', 'Key': 121, 'Character': 'OWEN', 'Dialog': 'Yeah?'},
#  {'Movie': 'Episode IV',
#   'Key': 122,
#   'Character': 'LUKE',
#   'Dialog': 'What about that one?'},
#  {'Movie': 'Episode IV',
#   'Key': 123,
#   'Character': 'OWEN',
#   'Dialog': "What about that blue one?  We'll take that one."},
#  {'Movie': 'Episode IV',
#   'Key': 124,
#   'Character': 'LUKE',
#   'Dialog': 'Yeah, take it away.'},
#  {'Movie': 'Episode IV',
#   'Key': 125,
#   'Character': 'THREEPIO',
#   'Dialog': "Uh, I'm quite sure you'll be very pleased with that one, sir.  He really is in first-class condition.  I've worked with him before.  Here he comes."},
#  {'Movie': 'Episode IV',
#   'Key': 126,
#   'Character': 'LUKE',
#   'Dialog': "Okay, let's go."},
#  {'Movie': 'Episode IV',
#   'Key': 127,
#   'Character': 'THREEPIO',
#   'Dialog': "Now, don't forget this!  Why I should stick my neck out for you is quite beyond my capacity!"},
#  {'Movie': 'Episode IV',
#   'Key': 128,
#   'Character': 'THREEPIO',
#   'Dialog': "Thank the maker!  This oil bath is going to feel so good.  I've got such a bad case of dust contamination, I can barely move!"},
#  {'Movie': 'Episode IV',
#   'Key': 129,
#   'Character': 'LUKE',
#   'Dialog': "It just isn't fair.  Oh, Biggs is right.  I'm never gonna get out of here!"},
#  {'Movie': 'Episode IV',
#   'Key': 130,
#   'Character': 'THREEPIO',
#   'Dialog': 'Is there anything I might do to help? '},
#  {'Movie': 'Episode IV',
#   'Key': 131,
#   'Character': 'LUKE',
#   'Dialog': 'Well, not unless you can alter time, speed up the harvest, or teleport me off this rock!'},
#  {'Movie': 'Episode IV',
#   'Key': 132,
#   'Character': 'THREEPIO',
#   'Dialog': "I don't think so, sir.  I'm only a droid and not very knowledgeable about such things.  Not on this planet, anyways.  As a matter of fact, I'm not even sure which planet I'm on."},
#  {'Movie': 'Episode IV',
#   'Key': 133,
#   'Character': 'LUKE',
#   'Dialog': "Well, if there's a bright center to the universe, you're on the planet that it's farthest from."},
#  {'Movie': 'Episode IV',
#   'Key': 134,
#   'Character': 'THREEPIO',
#   'Dialog': 'I see, sir.'},
#  {'Movie': 'Episode IV',
#   'Key': 135,
#   'Character': 'LUKE',
#   'Dialog': 'Uh, you can call me Luke.'},
#  {'Movie': 'Episode IV',
#   'Key': 136,
#   'Character': 'THREEPIO',
#   'Dialog': 'I see, sir Luke.'},
#  {'Movie': 'Episode IV',
#   'Key': 137,
#   'Character': 'LUKE',
#   'Dialog': 'Just Luke.'},
#  {'Movie': 'Episode IV',
#   'Key': 138,
#   'Character': 'THREEPIO',
#   'Dialog': 'And I am See-Threepio, human-cyborg relations, and this is my counterpart, Artoo-Detoo.'},
#  {'Movie': 'Episode IV', 'Key': 139, 'Character': 'LUKE', 'Dialog': 'Hello.'},
#  {'Movie': 'Episode IV',
#   'Key': 140,
#   'Character': 'LUKE',
#   'Dialog': 'You got a lot of carbon scoring here.  It looks like you boys have seen a lot of action.'},
#  {'Movie': 'Episode IV',
#   'Key': 141,
#   'Character': 'THREEPIO',
#   'Dialog': "With all we've been through, sometimes I'm amazed we're in as good condition as we are, what with the Rebellion and all."},
#  {'Movie': 'Episode IV',
#   'Key': 142,
#   'Character': 'LUKE',
#   'Dialog': 'You know of the Rebellion against the Empire?'},
#  {'Movie': 'Episode IV',
#   'Key': 143,
#   'Character': 'THREEPIO',
#   'Dialog': "That's how we came to be in your service, if you take my meaning, sir."},
#  {'Movie': 'Episode IV',
#   'Key': 144,
#   'Character': 'LUKE',
#   'Dialog': 'Have you been in many battles?'},
#  {'Movie': 'Episode IV',
#   'Key': 145,
#   'Character': 'THREEPIO',
#   'Dialog': "Several, I think.  Actually, there's not much to tell.  I'm not much more than an interpreter, and not very good at telling stories.  Well, not at making them interesting, anyways."},
#  {'Movie': 'Episode IV',
#   'Key': 146,
#   'Character': 'LUKE',
#   'Dialog': "Well, my little friend, you've got something jammed in here real good.  Were you on a starcruiser or..."},
#  {'Movie': 'Episode IV',
#   'Key': 147,
#   'Character': 'LEIA',
#   'Dialog': "Help me, Obi-Wan Kenobi.  You'remy only hope."},
#  {'Movie': 'Episode IV',
#   'Key': 148,
#   'Character': 'LUKE',
#   'Dialog': "What's this?"},
#  {'Movie': 'Episode IV',
#   'Key': 149,
#   'Character': 'THREEPIO',
#   'Dialog': 'What is what?!?  He asked you a question...What is that?'},
#  {'Movie': 'Episode IV',
#   'Key': 150,
#   'Character': 'LEIA',
#   'Dialog': "Help me, Obi-Wan Kenobi.  You're my only hope.  Help me, Obi-Wan Kenobi.  You're my only hope."},
#  {'Movie': 'Episode IV',
#   'Key': 151,
#   'Character': 'THREEPIO',
#   'Dialog': "Oh, he says it's nothing, sir.  Merely a malfunction.  Old data.  Pay it no mind."},
#  {'Movie': 'Episode IV',
#   'Key': 152,
#   'Character': 'LUKE',
#   'Dialog': "Who is she?  She's beautiful."},
#  {'Movie': 'Episode IV',
#   'Key': 153,
#   'Character': 'THREEPIO',
#   'Dialog': "I'm afraid I'm not quite sure, sir."},
#  {'Movie': 'Episode IV',
#   'Key': 154,
#   'Character': 'LEIA',
#   'Dialog': 'Help me, Obi-Wan Kenobi...'},
#  {'Movie': 'Episode IV',
#   'Key': 155,
#   'Character': 'THREEPIO',
#   'Dialog': 'I think she was a passenger on our last voyage.  A person of some importance, sir - I believe.  Our captain was attached to...'},
#  {'Movie': 'Episode IV',
#   'Key': 156,
#   'Character': 'LUKE',
#   'Dialog': 'Is there more to this recording?'},
#  {'Movie': 'Episode IV',
#   'Key': 157,
#   'Character': 'THREEPIO',
#   'Dialog': "Behave yourself, Artoo.  You're going to get us in trouble.  It's all right, you can trust him.  He's our new master."},
#  {'Movie': 'Episode IV',
#   'Key': 158,
#   'Character': 'THREEPIO',
#   'Dialog': "He says he's the property of Obi-Wan Kenobi, a resident of these parts.  And it's a private message for him.  Quite frankly, sir, I don't know what he's talking about.  Our last master was Captain Antilles, but with what we've been through, this little R2 unit has become a bit eccentric."},
#  {'Movie': 'Episode IV',
#   'Key': 159,
#   'Character': 'LUKE',
#   'Dialog': 'Obi-Wan Kenobi?  I wonder if he means old Ben Kenobi?'},
#  {'Movie': 'Episode IV',
#   'Key': 160,
#   'Character': 'THREEPIO',
#   'Dialog': "I beg your pardon, sir, but do you know what he's talking about?"},
#  {'Movie': 'Episode IV',
#   'Key': 161,
#   'Character': 'LUKE',
#   'Dialog': "Well, I don't know anyone named Obi-Wan, but old Ben lives out beyond the dune sea.  He's kind of a strange old hermit."},
#  {'Movie': 'Episode IV',
#   'Key': 162,
#   'Character': 'LUKE',
#   'Dialog': "I wonder who she is.  It sounds like she's in trouble.  I'd better play back the whole thing."},
#  {'Movie': 'Episode IV',
#   'Key': 163,
#   'Character': 'THREEPIO',
#   'Dialog': 'He says the restraining bolt has short circuited his recording system.  He suggests that if you remove the bolt, he might be able to play back the entire recording.'},
#  {'Movie': 'Episode IV',
#   'Key': 164,
#   'Character': 'LUKE',
#   'Dialog': "H'm?  Oh, yeah, well, I guess you're too small to run away on me if I take this off!  Okay."},
#  {'Movie': 'Episode IV',
#   'Key': 165,
#   'Character': 'LUKE',
#   'Dialog': 'There you go.'},
#  {'Movie': 'Episode IV',
#   'Key': 166,
#   'Character': 'LUKE',
#   'Dialog': "Well, wait a minute.  Where'd she go?  Bring her back!  Play back the entire message."},
#  {'Movie': 'Episode IV',
#   'Key': 167,
#   'Character': 'THREEPIO',
#   'Dialog': "been playing.  The one you're carrying inside your rusty innards! "},
#  {'Movie': 'Episode IV',
#   'Key': 168,
#   'Character': 'AUNT BERU',
#   'Dialog': 'Luke?  Luke!  Come to dinner!'},
#  {'Movie': 'Episode IV',
#   'Key': 169,
#   'Character': 'LUKE',
#   'Dialog': "All right, I'll be right there, Aunt Beru."},
#  {'Movie': 'Episode IV',
#   'Key': 170,
#   'Character': 'THREEPIO',
#   'Dialog': "I'm sorry, sir, but he appears to have picked up a slight flutter."},
#  {'Movie': 'Episode IV',
#   'Key': 171,
#   'Character': 'LUKE',
#   'Dialog': "Well, see what you can do with him.  I'll be right back."},
#  {'Movie': 'Episode IV',
#   'Key': 172,
#   'Character': 'THREEPIO',
#   'Dialog': 'Just you reconsider playing that message for him.'},
#  {'Movie': 'Episode IV',
#   'Key': 173,
#   'Character': 'THREEPIO',
#   'Dialog': "No, I don't think he likes you at all."},
#  {'Movie': 'Episode IV',
#   'Key': 174,
#   'Character': 'THREEPIO',
#   'Dialog': "No, I don't like you either."},
#  {'Movie': 'Episode IV',
#   'Key': 175,
#   'Character': 'LUKE',
#   'Dialog': 'You know, I think that R2 unit we bought might have been stolen.'},
#  {'Movie': 'Episode IV',
#   'Key': 176,
#   'Character': 'OWEN',
#   'Dialog': 'What makes you think that?'},
#  {'Movie': 'Episode IV',
#   'Key': 177,
#   'Character': 'LUKE',
#   'Dialog': 'Well, I stumbled across a recording while I was cleaning him.  He says he belongs to someone called Obi-Wan Kenobi.'},
#  {'Movie': 'Episode IV',
#   'Key': 178,
#   'Character': 'LUKE',
#   'Dialog': "I thought he might have meant Ben.  Do you know what he's talking about?  Well, I wonder if he's related to Ben."},
#  {'Movie': 'Episode IV',
#   'Key': 179,
#   'Character': 'OWEN',
#   'Dialog': "That old man's just a crazy wizard.  Tomorrow I want you to take that R2 unit into Anchorhead and have its memory flushed.  That'll be the end of it.  It belongs to us now."},
#  {'Movie': 'Episode IV',
#   'Key': 180,
#   'Character': 'LUKE',
#   'Dialog': 'But what if this Obi-Wan comes looking for him?'},
#  {'Movie': 'Episode IV',
#   'Key': 181,
#   'Character': 'OWEN',
#   'Dialog': "He won't, I don't think he exists any more.  He died about the same time as your father."},
#  {'Movie': 'Episode IV',
#   'Key': 182,
#   'Character': 'LUKE',
#   'Dialog': 'He knew my father?'},
#  {'Movie': 'Episode IV',
#   'Key': 183,
#   'Character': 'OWEN',
#   'Dialog': 'I told you to forget it.  Your only concern is to prepare the new droids for tomorrow.  In the morning I want them on the south ridge working out those condensers.'},
#  {'Movie': 'Episode IV',
#   'Key': 184,
#   'Character': 'LUKE',
#   'Dialog': 'Yes, sir.  I think those new droids are going to work out fine.  In fact, I, uh, was also thinking about our agreement about my staying on another season.  And if these new droids do work out, I want to transmit my application to the Academy this year.'},
#  {'Movie': 'Episode IV',
#   'Key': 185,
#   'Character': 'OWEN',
#   'Dialog': 'You mean the next semester before harvest?'},
#  {'Movie': 'Episode IV',
#   'Key': 186,
#   'Character': 'LUKE',
#   'Dialog': "Sure, there're more than enough droids."},
#  {'Movie': 'Episode IV',
#   'Key': 187,
#   'Character': 'OWEN',
#   'Dialog': "Harvest is when I need you the most.  Only one more season.  This year we'll make enough on the harvest so I'll be able to hire some more hands.  And then you can go to the Academy next year."},
#  {'Movie': 'Episode IV',
#   'Key': 188,
#   'Character': 'OWEN',
#   'Dialog': 'You must understand I need you here, Luke.'},
#  {'Movie': 'Episode IV',
#   'Key': 189,
#   'Character': 'LUKE',
#   'Dialog': "But it's a whole 'nother year."},
#  {'Movie': 'Episode IV',
#   'Key': 190,
#   'Character': 'OWEN',
#   'Dialog': "Look, it's only one more season."},
#  {'Movie': 'Episode IV',
#   'Key': 191,
#   'Character': 'LUKE',
#   'Dialog': "Yeah, that's what you said last year when Biggs and Tank left."},
#  {'Movie': 'Episode IV',
#   'Key': 192,
#   'Character': 'AUNT BERU',
#   'Dialog': 'Where are you going?'},
#  {'Movie': 'Episode IV',
#   'Key': 193,
#   'Character': 'LUKE',
#   'Dialog': "It looks like I'm going nowhere.  I have to finish cleaning those droids."},
#  {'Movie': 'Episode IV',
#   'Key': 194,
#   'Character': 'AUNT BERU',
#   'Dialog': "Owen, he can't stay here forever.  Most of his friends have gone.  It means so much to him."},
#  {'Movie': 'Episode IV',
#   'Key': 195,
#   'Character': 'OWEN',
#   'Dialog': "I'll make it up to him next year.  I promise."},
#  {'Movie': 'Episode IV',
#   'Key': 196,
#   'Character': 'AUNT BERU',
#   'Dialog': "Luke's just not a farmer, Owen.  He has too much of his father in him."},
#  {'Movie': 'Episode IV',
#   'Key': 197,
#   'Character': 'OWEN',
#   'Dialog': "That's what I'm afraid of."},
#  {'Movie': 'Episode IV',
#   'Key': 198,
#   'Character': 'LUKE',
#   'Dialog': 'What are you doing hiding there?'},
#  {'Movie': 'Episode IV',
#   'Key': 199,
#   'Character': 'THREEPIO',
#   'Dialog': "It wasn't my fault, sir.  Please don't deactivate me.  I told him not to go, but he's faulty, malfunctioning; kept babbling on about his mission."},
#  {'Movie': 'Episode IV', 'Key': 200, 'Character': 'LUKE', 'Dialog': 'Oh, no!'},
#  {'Movie': 'Episode IV',
#   'Key': 201,
#   'Character': 'THREEPIO',
#   'Dialog': "That R2 unit has always been a problem.  These astro-droids are getting quite out of hand.  Even I can't understand their logic at times. "},
#  {'Movie': 'Episode IV',
#   'Key': 202,
#   'Character': 'LUKE',
#   'Dialog': "How could I be so stupid?  He's nowhere in sight.  Blast it!"},
#  {'Movie': 'Episode IV',
#   'Key': 203,
#   'Character': 'THREEPIO',
#   'Dialog': "Pardon me, sir, but couldn't we go after him?"},
#  {'Movie': 'Episode IV',
#   'Key': 204,
#   'Character': 'LUKE',
#   'Dialog': "It's too dangerous with all the Sand People around.  We'll have to wait until morning."},
#  {'Movie': 'Episode IV',
#   'Key': 205,
#   'Character': 'OWEN',
#   'Dialog': "Luke, I'm shutting the power down for the night."},
#  {'Movie': 'Episode IV',
#   'Key': 206,
#   'Character': 'LUKE',
#   'Dialog': "All right, I'll be there in a few minutes.  Boy, am I gonna get it."},
#  {'Movie': 'Episode IV',
#   'Key': 207,
#   'Character': 'LUKE',
#   'Dialog': 'You know that little droid is going to cause me a lot of trouble.'},
#  {'Movie': 'Episode IV',
#   'Key': 208,
#   'Character': 'THREEPIO',
#   'Dialog': 'Oh, he excels at that, sir.'},
#  {'Movie': 'Episode IV',
#   'Key': 209,
#   'Character': 'OWEN',
#   'Dialog': 'Luke?  Luke?  Luke?  Where could he be loafing now!'},
#  {'Movie': 'Episode IV',
#   'Key': 210,
#   'Character': 'OWEN',
#   'Dialog': 'Have you seen Luke this morning?'},
#  {'Movie': 'Episode IV',
#   'Key': 211,
#   'Character': 'AUNT BERU',
#   'Dialog': 'He said he had some things to do before he started today, so he left early.'},
#  {'Movie': 'Episode IV',
#   'Key': 212,
#   'Character': 'OWEN',
#   'Dialog': 'Uh?  Did he take those two new droids with him?'},
#  {'Movie': 'Episode IV',
#   'Key': 213,
#   'Character': 'AUNT BERU',
#   'Dialog': 'I think so.'},
#  {'Movie': 'Episode IV',
#   'Key': 214,
#   'Character': 'OWEN',
#   'Dialog': "Well, he'd better have those units in the south range repaired bemidday or there'll be hell to pay!"},
#  {'Movie': 'Episode IV',
#   'Key': 215,
#   'Character': 'LUKE',
#   'Dialog': "How's that."},
#  {'Movie': 'Episode IV',
#   'Key': 216,
#   'Character': 'LUKE',
#   'Dialog': "Old Ben Kenobi lives out in this direction somewhere, but I don't see how that R2 unit could have come this far.  We must have missed him.  Uncle Owen isn't going to take this very well."},
#  {'Movie': 'Episode IV',
#   'Key': 217,
#   'Character': 'THREEPIO',
#   'Dialog': 'Sir, would it help if you told him it was my fault.'},
#  {'Movie': 'Episode IV',
#   'Key': 218,
#   'Character': 'LUKE',
#   'Dialog': "Sure.  He needs you.  He'd probably only deactivate you for a day or so..."},
#  {'Movie': 'Episode IV',
#   'Key': 219,
#   'Character': 'THREEPIO',
#   'Dialog': "Deactivate!  Well, on the other hand if you hadn't removed his restraining bolt..."},
#  {'Movie': 'Episode IV',
#   'Key': 220,
#   'Character': 'LUKE',
#   'Dialog': "Wait, there's something dead ahead on the scanner.  It looks like our droid... hit the accelerator."},
#  {'Movie': 'Episode IV',
#   'Key': 221,
#   'Character': 'LUKE',
#   'Dialog': "Hey, whoa, just where do you think you're going?"},
#  {'Movie': 'Episode IV',
#   'Key': 222,
#   'Character': 'THREEPIO',
#   'Dialog': "Master Luke here is your rightful owner.  We'll have no more of this Obi-Wan Kenobi jibberish... and don't talk to me of your mission, either.  You're fortunate he doesn't blast you into a million pieces right here."},
#  {'Movie': 'Episode IV',
#   'Key': 223,
#   'Character': 'LUKE',
#   'Dialog': "Well, come on. It's getting late.  I only hope we can get back before Uncle Owen really blows up."},
#  {'Movie': 'Episode IV',
#   'Key': 224,
#   'Character': 'THREEPIO',
#   'Dialog': "If you don't mind my saying so, sir, I think you should deactivate the little fugitive until you've gotten him back to your workshop."},
#  {'Movie': 'Episode IV',
#   'Key': 225,
#   'Character': 'LUKE',
#   'Dialog': "No, he's not going to try anything."},
#  {'Movie': 'Episode IV',
#   'Key': 226,
#   'Character': 'LUKE',
#   'Dialog': "What's wrong with him now?"},
#  {'Movie': 'Episode IV',
#   'Key': 227,
#   'Character': 'THREEPIO',
#   'Dialog': 'Oh my... sir, he says there are several creatures approaching from the southeast.'},
#  {'Movie': 'Episode IV',
#   'Key': 228,
#   'Character': 'LUKE',
#   'Dialog': "Sand People!  Or worse!  Come on, let's have a look.  Come on."},
#  {'Movie': 'Episode IV',
#   'Key': 229,
#   'Character': 'LUKE',
#   'Dialog': "There are two Banthas down there but I don't see any... wait a second, they're Sand People all right.  I can see one of them now."},
#  {'Movie': 'Episode IV',
#   'Key': 230,
#   'Character': 'BEN',
#   'Dialog': "Hello there!  Come here my little friend.  Don't be afraid."},
#  {'Movie': 'Episode IV',
#   'Key': 231,
#   'Character': 'BEN',
#   'Dialog': "Don't worry, he'll be all right."},
#  {'Movie': 'Episode IV',
#   'Key': 232,
#   'Character': 'LUKE',
#   'Dialog': 'What happened?'},
#  {'Movie': 'Episode IV',
#   'Key': 233,
#   'Character': 'BEN',
#   'Dialog': "Rest easy, son, you've had a busy day.  You're fortunate you're still in one piece."},
#  {'Movie': 'Episode IV',
#   'Key': 234,
#   'Character': 'LUKE',
#   'Dialog': 'Ben?  Ben Kenobi!  Boy, am I glad to see you! '},
#  {'Movie': 'Episode IV',
#   'Key': 235,
#   'Character': 'BEN',
#   'Dialog': 'The Jundland Wastes are not to be traveled lightly.  Tell me, young Luke, what brings you out this far?'},
#  {'Movie': 'Episode IV',
#   'Key': 236,
#   'Character': 'LUKE',
#   'Dialog': "Oh, this little droid!  I think he's searching for his former master...  I've never seen such devotion in a droid before... there seems tobe no stopping him.  He claims to be the property of an Obi-Wan Kenobi.  Is he a relative of yours?  Do you know who he's talking about?"},
#  {'Movie': 'Episode IV',
#   'Key': 237,
#   'Character': 'BEN',
#   'Dialog': "Obi-Wan Kenobi... Obi-Wan?  Now thats a name I haven't heard in a long time... a long time."},
#  {'Movie': 'Episode IV',
#   'Key': 238,
#   'Character': 'LUKE',
#   'Dialog': 'I think my uncle knew him.  He said he was dead.'},
#  {'Movie': 'Episode IV',
#   'Key': 239,
#   'Character': 'BEN',
#   'Dialog': "Oh, he's not dead, no... not yet."},
#  {'Movie': 'Episode IV',
#   'Key': 240,
#   'Character': 'LUKE',
#   'Dialog': 'You know him!'},
#  {'Movie': 'Episode IV',
#   'Key': 241,
#   'Character': 'BEN',
#   'Dialog': "Well of course, of course I know him.  He's me!  I haven't gone by the name Obi-Wan since oh, before you were born."},
#  {'Movie': 'Episode IV',
#   'Key': 242,
#   'Character': 'LUKE',
#   'Dialog': 'Then the droid does belong to you.'},
#  {'Movie': 'Episode IV',
#   'Key': 243,
#   'Character': 'BEN',
#   'Dialog': "Don't seem to remember ever owning a droid.  Very interesting... "},
#  {'Movie': 'Episode IV',
#   'Key': 244,
#   'Character': 'BEN',
#   'Dialog': 'I think we better get indoors.  The Sand People are easily startled but they will soon be back and in greater numbers.'},
#  {'Movie': 'Episode IV',
#   'Key': 245,
#   'Character': 'LUKE',
#   'Dialog': '... Threepio!'},
#  {'Movie': 'Episode IV',
#   'Key': 246,
#   'Character': 'THREEPIO',
#   'Dialog': 'Where am I?  I must have taken a bad step...'},
#  {'Movie': 'Episode IV',
#   'Key': 247,
#   'Character': 'LUKE',
#   'Dialog': "Can you stand?  We've got to get out of here before the Sand People return."},
#  {'Movie': 'Episode IV',
#   'Key': 248,
#   'Character': 'THREEPIO',
#   'Dialog': "I don't think I can make it.  You go on, Master Luke.  There's no sense in you risking yourself on my account.  I'm done for."},
#  {'Movie': 'Episode IV',
#   'Key': 249,
#   'Character': 'LUKE',
#   'Dialog': "No, you're not.  What kind of talk is that?"},
#  {'Movie': 'Episode IV',
#   'Key': 250,
#   'Character': 'BEN',
#   'Dialog': "Quickly, son... they're on the move."},
#  {'Movie': 'Episode IV',
#   'Key': 251,
#   'Character': 'LUKE',
#   'Dialog': "No, my father didn't fight in the wars.  He was a navigator on a spice freighter."},
#  {'Movie': 'Episode IV',
#   'Key': 252,
#   'Character': 'BEN',
#   'Dialog': "That's what your uncle told you.  He didn't hold with your father's ideals.  Thought he should have stayed here and not gotten involved."},
#  {'Movie': 'Episode IV',
#   'Key': 253,
#   'Character': 'LUKE',
#   'Dialog': 'You fought in the Clone Wars?'},
#  {'Movie': 'Episode IV',
#   'Key': 254,
#   'Character': 'BEN',
#   'Dialog': 'Yes, I was once a Jedi Knight the same as your father.'},
#  {'Movie': 'Episode IV',
#   'Key': 255,
#   'Character': 'LUKE',
#   'Dialog': "I wish I'd known him."},
#  {'Movie': 'Episode IV',
#   'Key': 256,
#   'Character': 'BEN',
#   'Dialog': "He was the best star-pilot in the galaxy, and a cunning warrior.  I understand you've become quite a good pilot yourself.  And he was a good friend.  Which reminds me..."},
#  {'Movie': 'Episode IV',
#   'Key': 257,
#   'Character': 'BEN',
#   'Dialog': "I have something here for you.  Your father wanted you to have this when you were old enough, but your uncle wouldn't allow it.  He feared you might follow old Obi-Wan on some damned-fool idealistic crusade like your father did. "},
#  {'Movie': 'Episode IV',
#   'Key': 258,
#   'Character': 'THREEPIO',
#   'Dialog': "Sir, if you'll not be needing me, I'll close down for awhile."},
#  {'Movie': 'Episode IV',
#   'Key': 259,
#   'Character': 'LUKE',
#   'Dialog': 'Sure, go ahead.'},
#  {'Movie': 'Episode IV',
#   'Key': 260,
#   'Character': 'LUKE',
#   'Dialog': 'What is it?'},
#  {'Movie': 'Episode IV',
#   'Key': 261,
#   'Character': 'BEN',
#   'Dialog': 'Your fathers lightsaber.  This is the weapon of a Jedi Knight.  Not as clumsy or as random as a blaster.'},
#  {'Movie': 'Episode IV',
#   'Key': 262,
#   'Character': 'BEN',
#   'Dialog': 'An elegant weapon for a morecivilized time.  For over a thousand generations the Jedi Knights were the guardians of peace and justice in the Old Republic.  Before the dark times, before the Empire.'},
#  {'Movie': 'Episode IV',
#   'Key': 263,
#   'Character': 'LUKE',
#   'Dialog': 'How did my father die?'},
#  {'Movie': 'Episode IV',
#   'Key': 264,
#   'Character': 'BEN',
#   'Dialog': 'A young Jedi named Darth Vader, who was a pupil of mine until he turned to evil, helped the Empire hunt down and destroy the Jedi Knights.  He betrayed and murdered your father.  Now the Jedi are all but extinct.  Vader was seduced by the dark side of the Force.'},
#  {'Movie': 'Episode IV',
#   'Key': 265,
#   'Character': 'LUKE',
#   'Dialog': 'The Force?'},
#  {'Movie': 'Episode IV',
#   'Key': 266,
#   'Character': 'BEN',
#   'Dialog': "Well, the Force is what gives the Jedi his power.  It's an energy field created by all living things.  It surrounds us and penetrates us.  It binds the galaxy together."},
#  {'Movie': 'Episode IV',
#   'Key': 267,
#   'Character': 'BEN',
#   'Dialog': "Now, let's see if we can't figure out what you are, my little friend.  And where you come from."},
#  {'Movie': 'Episode IV',
#   'Key': 268,
#   'Character': 'LUKE',
#   'Dialog': 'I saw part of the message he was...'},
#  {'Movie': 'Episode IV',
#   'Key': 269,
#   'Character': 'BEN',
#   'Dialog': 'I seem to have found it.'},
#  {'Movie': 'Episode IV',
#   'Key': 270,
#   'Character': 'LEIA',
#   'Dialog': "General Kenobi, years ago you served my father in the Clone Wars.  Now he begs you to help him in his struggle against the Empire.  I regret that I am unable to present my father's request to you in person, but my ship has fallen under attack and I'm afraid my mission to bring you to Alderaan has failed.  I have placed information vital to the survival of the Rebellion into the memory systems of this R2 unit.  My father will know how to retrieve it.  You must see this droid safely delivered to him on Alderaan.  This is our most desperate hour.  Help me, Obi-Wan Kenobi, you're my only hope."},
#  {'Movie': 'Episode IV',
#   'Key': 271,
#   'Character': 'BEN',
#   'Dialog': "You must learn the ways of the Force if you're to come with me to Alderaan."},
#  {'Movie': 'Episode IV',
#   'Key': 272,
#   'Character': 'LUKE',
#   'Dialog': "Alderaan?  I'm not going to Alderaan.  I've got to go home.  It's late, I'm in for it as it is."},
#  {'Movie': 'Episode IV',
#   'Key': 273,
#   'Character': 'BEN',
#   'Dialog': "I need your help, Luke.  I'm getting too old for this sort of thing.She needs your help."},
#  {'Movie': 'Episode IV',
#   'Key': 274,
#   'Character': 'LUKE',
#   'Dialog': "I can't get involved!  I've got work to do!  It's not that I like the Empire.  I hate it!  But there's nothing I can do about it right now.  It's such a long way from here."},
#  {'Movie': 'Episode IV',
#   'Key': 275,
#   'Character': 'BEN',
#   'Dialog': "That's your uncle talking."},
#  {'Movie': 'Episode IV',
#   'Key': 276,
#   'Character': 'LUKE',
#   'Dialog': 'Oh, God, my uncle.  How am I ever going to explain this?'},
#  {'Movie': 'Episode IV',
#   'Key': 277,
#   'Character': 'BEN',
#   'Dialog': 'Learn about the Force, Luke.'},
#  {'Movie': 'Episode IV',
#   'Key': 278,
#   'Character': 'LUKE',
#   'Dialog': "Look, I can take you as far as Anchorhead.  You can get a transport there to Mos Eisley or wherever you're going."},
#  {'Movie': 'Episode IV',
#   'Key': 279,
#   'Character': 'BEN',
#   'Dialog': 'You must do what you feel is right, of course.'},
#  {'Movie': 'Episode IV',
#   'Key': 280,
#   'Character': 'TAGGE',
#   'Dialog': "Until this battle station is fully operational we are vulnerable.  The Rebel Alliance is too well equipped.  They're more dangerous than you realize."},
#  {'Movie': 'Episode IV',
#   'Key': 281,
#   'Character': 'MOTTI',
#   'Dialog': 'Dangerous to your starfleet, Commander; not to this battle station!'},
#  {'Movie': 'Episode IV',
#   'Key': 282,
#   'Character': 'TAGGE',
#   'Dialog': 'The Rebellion will continue to gain support in the Imperial Senate as long as....'},
#  {'Movie': 'Episode IV',
#   'Key': 283,
#   'Character': 'TARKIN',
#   'Dialog': "The Imperial Senate will no longer be of any concern to us.  I've just received word that the Emperor has dissolved the council permanently.  The last remnants of the Old Republic have been swept away."},
#  {'Movie': 'Episode IV',
#   'Key': 284,
#   'Character': 'TAGGE',
#   'Dialog': "That's impossible!  How will the Emperor maintain control without the bureaucracy?"},
#  {'Movie': 'Episode IV',
#   'Key': 285,
#   'Character': 'TARKIN',
#   'Dialog': 'The regional governors now have direct control over territories.  Fear will keep the local systems in line.  Fear of this battle station.'},
#  {'Movie': 'Episode IV',
#   'Key': 286,
#   'Character': 'TAGGE',
#   'Dialog': 'And what of the Rebellion?  If the Rebels have obtained a complete technical readout of this station, it is possible, however unlikely, that they might find a weakness and exploit it.'},
#  {'Movie': 'Episode IV',
#   'Key': 287,
#   'Character': 'VADER',
#   'Dialog': 'The plans you refer to will soon be back in our hands.'},
#  {'Movie': 'Episode IV',
#   'Key': 288,
#   'Character': 'MOTTI',
#   'Dialog': "Any attack made by the Rebels against this station would be a useless gesture, no matter what technical data they've obtained.  This station is now the ultimate power in the universe.  I suggest we use it!"},
#  {'Movie': 'Episode IV',
#   'Key': 289,
#   'Character': 'VADER',
#   'Dialog': "Don't be too proud of this technological terror you've constructed.  The ability to destroy a planet is insignificant next to the power of the Force."},
#  {'Movie': 'Episode IV',
#   'Key': 290,
#   'Character': 'MOTTI',
#   'Dialog': "Don't try to frighten us with your sorcerer's ways, Lord Vader.  Your sad devotion to that ancient religion has not helped you conjure up the stolen data tapes, or given you clairvoyance enough to find the Rebel's hidden fort..."},
#  {'Movie': 'Episode IV',
#   'Key': 291,
#   'Character': 'VADER',
#   'Dialog': 'I find your lack of faith disturbing.'},
#  {'Movie': 'Episode IV',
#   'Key': 292,
#   'Character': 'TARKIN',
#   'Dialog': 'Enough of this!  Vader, release him!'},
#  {'Movie': 'Episode IV',
#   'Key': 293,
#   'Character': 'VADER',
#   'Dialog': 'As you wish.'},
#  {'Movie': 'Episode IV',
#   'Key': 294,
#   'Character': 'TARKIN',
#   'Dialog': 'This bickering is pointless.  Lord Vader will provide us with the location of the Rebel fortress by the time this station is operational.  We will then crush the Rebellion with one swift stroke.'},
#  {'Movie': 'Episode IV',
#   'Key': 295,
#   'Character': 'LUKE',
#   'Dialog': "It looks like Sand People did this, all right.  Look, here are gaffi sticks, bantha tracks.  It's just... I never heard of them hitting anything this big before."},
#  {'Movie': 'Episode IV',
#   'Key': 296,
#   'Character': 'BEN',
#   'Dialog': "They didn't.  But we are meant to think they did.  These tracks are side by side.  Sand People always ride single file to hide there numbers."},
#  {'Movie': 'Episode IV',
#   'Key': 297,
#   'Character': 'LUKE',
#   'Dialog': 'These are the same Jawas that sold us Artoo and Threepio.'},
#  {'Movie': 'Episode IV',
#   'Key': 298,
#   'Character': 'BEN',
#   'Dialog': 'And these blast points, too accurate for Sand People.  Only Imperial stormtroopers are so precise.'},
#  {'Movie': 'Episode IV',
#   'Key': 299,
#   'Character': 'LUKE',
#   'Dialog': 'Why would Imperial troops want to slaughter Jawas?'},
#  {'Movie': 'Episode IV',
#   'Key': 300,
#   'Character': 'LUKE',
# ...
#   'Key': 864,
#   'Character': 'LUKE',
#   'Dialog': "This is Red Five!  I'm going in!"},
#  {'Movie': 'Episode IV',
#   'Key': 865,
#   'Character': 'BIGGS',
#   'Dialog': 'Luke, pull up!'},
#  {'Movie': 'Episode IV',
#   'Key': 866,
#   'Character': 'BIGGS',
#   'Dialog': 'Are you all right?'},
#  {'Movie': 'Episode IV',
#   'Key': 867,
#   'Character': 'LUKE',
#   'Dialog': "I got a little cooked, but I'm okay."},
#  {'Movie': 'Episode IV',
#   'Key': 868,
#   'Character': 'ASTRO-OFFICER',
#   'Dialog': "We count thirty Rebel ships, Lord Vader.  But they're so small they're evading our turbo-lasers!"},
#  {'Movie': 'Episode IV',
#   'Key': 869,
#   'Character': 'VADER',
#   'Dialog': "We'll have to destroy them ship to ship.  Get the crews to their fighters."},
#  {'Movie': 'Episode IV',
#   'Key': 870,
#   'Character': 'RED LEADER',
#   'Dialog': "Luke, let me know when you're going in."},
#  {'Movie': 'Episode IV',
#   'Key': 871,
#   'Character': 'LUKE',
#   'Dialog': "I'm on my way in now..."},
#  {'Movie': 'Episode IV',
#   'Key': 872,
#   'Character': 'RED LEADER',
#   'Dialog': "Watch yourself!  There's a lot of fire coming from the right side of that deflection tower."},
#  {'Movie': 'Episode IV',
#   'Key': 873,
#   'Character': 'LUKE',
#   'Dialog': "I'm on it."},
#  {'Movie': 'Episode IV',
#   'Key': 874,
#   'Character': 'CONTROL OFFICER',
#   'Dialog': "Squad leaders, we've picked up a new group of signals.  Enemy fighters coming your way."},
#  {'Movie': 'Episode IV',
#   'Key': 875,
#   'Character': 'LUKE',
#   'Dialog': "My scope's negative.  I don't see anything."},
#  {'Movie': 'Episode IV',
#   'Key': 876,
#   'Character': 'RED LEADER',
#   'Dialog': "Keep up your visual scanning.  With all this jamming, they'll be on top of you before your scope can pick them up."},
#  {'Movie': 'Episode IV',
#   'Key': 877,
#   'Character': 'RED LEADER',
#   'Dialog': "Biggs!  You've picked one up... watch it!"},
#  {'Movie': 'Episode IV',
#   'Key': 878,
#   'Character': 'BIGGS',
#   'Dialog': "I can't see it!  Where is he?!"},
#  {'Movie': 'Episode IV',
#   'Key': 879,
#   'Character': 'BIGGS',
#   'Dialog': "He's on me tight, I can't shake him... I can't shake him."},
#  {'Movie': 'Episode IV',
#   'Key': 880,
#   'Character': 'LUKE',
#   'Dialog': "Hang on, Biggs, I'm coming in."},
#  {'Movie': 'Episode IV',
#   'Key': 881,
#   'Character': 'LUKE',
#   'Dialog': 'Got him!'},
#  {'Movie': 'Episode IV',
#   'Key': 882,
#   'Character': 'VADER',
#   'Dialog': 'Several fighters have broken off from the main group.  Come with me!'},
#  {'Movie': 'Episode IV',
#   'Key': 883,
#   'Character': 'BIGGS',
#   'Dialog': 'Pull in!  Luke... pull in!'},
#  {'Movie': 'Episode IV',
#   'Key': 884,
#   'Character': 'WEDGE',
#   'Dialog': 'Watch your back, Luke!'},
#  {'Movie': 'Episode IV',
#   'Key': 885,
#   'Character': 'WEDGE',
#   'Dialog': "Watch your back!  Fighter's above you, coming in!"},
#  {'Movie': 'Episode IV',
#   'Key': 886,
#   'Character': 'LUKE',
#   'Dialog': "I'm hit, but not bad."},
#  {'Movie': 'Episode IV',
#   'Key': 887,
#   'Character': 'LUKE',
#   'Dialog': 'Artoo, see what you can do with it.  Hang on back there.'},
#  {'Movie': 'Episode IV',
#   'Key': 888,
#   'Character': 'RED LEADER',
#   'Dialog': 'Red Six...'},
#  {'Movie': 'Episode IV',
#   'Key': 889,
#   'Character': 'RED LEADER',
#   'Dialog': 'Can you see Red Five?'},
#  {'Movie': 'Episode IV',
#   'Key': 890,
#   'Character': 'RED TEN',
#   'Dialog': "There's a heavy fire zone on this side. Red Five, where are you?"},
#  {'Movie': 'Episode IV',
#   'Key': 891,
#   'Character': 'LUKE',
#   'Dialog': "I can't shake him!"},
#  {'Movie': 'Episode IV',
#   'Key': 892,
#   'Character': 'WEDGE',
#   'Dialog': "I'm on him, Luke!"},
#  {'Movie': 'Episode IV',
#   'Key': 893,
#   'Character': 'WEDGE',
#   'Dialog': 'Hold on!'},
#  {'Movie': 'Episode IV',
#   'Key': 894,
#   'Character': 'LUKE',
#   'Dialog': 'Blast it!  Wedge where are you?'},
#  {'Movie': 'Episode IV',
#   'Key': 895,
#   'Character': 'LUKE',
#   'Dialog': 'Thanks, Wedge.'},
#  {'Movie': 'Episode IV',
#   'Key': 896,
#   'Character': 'BIGGS',
#   'Dialog': 'Good shooting, Wedge!'},
#  {'Movie': 'Episode IV',
#   'Key': 897,
#   'Character': 'GOLD LEADER',
#   'Dialog': 'Red Leader...'},
#  {'Movie': 'Episode IV',
#   'Key': 898,
#   'Character': 'GOLD LEADER',
#   'Dialog': "... This is Gold Leader.  We're starting out attack run."},
#  {'Movie': 'Episode IV',
#   'Key': 899,
#   'Character': 'RED LEADER',
#   'Dialog': 'I copy, Gold Leader.  Move into position.'},
#  {'Movie': 'Episode IV',
#   'Key': 900,
#   'Character': 'VADER',
#   'Dialog': 'Stay in attack formation!'},
#  {'Movie': 'Episode IV',
#   'Key': 901,
#   'Character': 'GOLD LEADER',
#   'Dialog': 'The exhaust post is...'},
#  {'Movie': 'Episode IV',
#   'Key': 902,
#   'Character': 'GOLD LEADER',
#   'Dialog': '... marked and locked in!'},
#  {'Movie': 'Episode IV',
#   'Key': 903,
#   'Character': 'GOLD LEADER',
#   'Dialog': 'Switch power to front deflection screens.'},
#  {'Movie': 'Episode IV',
#   'Key': 904,
#   'Character': 'GOLD LEADER',
#   'Dialog': 'How many guns do you think, Gold Five?'},
#  {'Movie': 'Episode IV',
#   'Key': 905,
#   'Character': 'GOLD FIVE',
#   'Dialog': "I'd say about twenty guns.  Some on the surface, some on the towers."},
#  {'Movie': 'Episode IV',
#   'Key': 906,
#   'Character': 'MASSASSI INTERCOM VOICE',
#   'Dialog': 'Death Star will be in range in five minutes. '},
#  {'Movie': 'Episode IV',
#   'Key': 907,
#   'Character': 'GOLD LEADER',
#   'Dialog': 'Switch to targeting computer.'},
#  {'Movie': 'Episode IV',
#   'Key': 908,
#   'Character': 'GOLD TWO',
#   'Dialog': "Computer's locked.  Getting a signal."},
#  {'Movie': 'Episode IV',
#   'Key': 909,
#   'Character': 'GOLD TWO',
#   'Dialog': "The guns... they've stopped!"},
#  {'Movie': 'Episode IV',
#   'Key': 910,
#   'Character': 'GOLD FIVE',
#   'Dialog': 'Stabilize your rear deflectors.  Watch for enemy fighters.'},
#  {'Movie': 'Episode IV',
#   'Key': 911,
#   'Character': 'GOLD LEADER',
#   'Dialog': "They've coming in!  Three marks at two ten."},
#  {'Movie': 'Episode IV',
#   'Key': 912,
#   'Character': 'VADER',
#   'Dialog': "I'll take them myself!  Cover me!"},
#  {'Movie': 'Episode IV',
#   'Key': 913,
#   'Character': 'WINGMAN',
#   'Dialog': 'Yes, sir.'},
#  {'Movie': 'Episode IV',
#   'Key': 914,
#   'Character': 'GOLD LEADER',
#   'Dialog': "I can't maneuver!"},
#  {'Movie': 'Episode IV',
#   'Key': 915,
#   'Character': 'GOLD FIVE',
#   'Dialog': 'Stay on target.'},
#  {'Movie': 'Episode IV',
#   'Key': 916,
#   'Character': 'GOLD LEADER',
#   'Dialog': "We're too close."},
#  {'Movie': 'Episode IV',
#   'Key': 917,
#   'Character': 'GOLD FIVE',
#   'Dialog': 'Stay on target!'},
#  {'Movie': 'Episode IV',
#   'Key': 918,
#   'Character': 'GOLD LEADER',
#   'Dialog': 'Loosen up!'},
#  {'Movie': 'Episode IV',
#   'Key': 919,
#   'Character': 'GOLD FIVE',
#   'Dialog': 'Gold Five to Red Leader...'},
#  {'Movie': 'Episode IV',
#   'Key': 920,
#   'Character': 'GOLD FIVE',
#   'Dialog': 'Lost Tiree, lost Dutch.'},
#  {'Movie': 'Episode IV',
#   'Key': 921,
#   'Character': 'RED LEADER',
#   'Dialog': 'I copy, Gold Five.'},
#  {'Movie': 'Episode IV',
#   'Key': 922,
#   'Character': 'GOLD FIVE',
#   'Dialog': 'They came from behind....'},
#  {'Movie': 'Episode IV',
#   'Key': 923,
#   'Character': 'OFFICER',
#   'Dialog': "We've analyzed their attack, sir, and there is a danger.  Should I have your ship standing by?"},
#  {'Movie': 'Episode IV',
#   'Key': 924,
#   'Character': 'TARKIN',
#   'Dialog': 'Evacuate?  In out moment of triumph?  I think you overestimate their chances!'},
#  {'Movie': 'Episode IV',
#   'Key': 925,
#   'Character': 'VOICE',
#   'Dialog': 'Rebel base, three minutes and closing.'},
#  {'Movie': 'Episode IV',
#   'Key': 926,
#   'Character': 'RED LEADER',
#   'Dialog': 'Red Group, this is Red Leader.'},
#  {'Movie': 'Episode IV',
#   'Key': 927,
#   'Character': 'RED LEADER',
#   'Dialog': 'Rendezvous at mark six point one.'},
#  {'Movie': 'Episode IV',
#   'Key': 928,
#   'Character': 'WEDGE',
#   'Dialog': 'This is Red Two.  Flying towards you.'},
#  {'Movie': 'Episode IV',
#   'Key': 929,
#   'Character': 'BIGGS',
#   'Dialog': 'Red Three, standing by.'},
#  {'Movie': 'Episode IV',
#   'Key': 930,
#   'Character': 'DODONNA',
#   'Dialog': 'Red Leader, this is Base One.  Keep half your group out of range for the next run.'},
#  {'Movie': 'Episode IV',
#   'Key': 931,
#   'Character': 'RED LEADER',
#   'Dialog': 'Copy, Base One.  Luke, take Red Two and Three.  Hold up here and wait for my signal... to start your run.'},
#  {'Movie': 'Episode IV',
#   'Key': 932,
#   'Character': 'RED LEADER',
#   'Dialog': 'This is it!'},
#  {'Movie': 'Episode IV',
#   'Key': 933,
#   'Character': 'RED TEN',
#   'Dialog': 'We should be able to see it by now.'},
#  {'Movie': 'Episode IV',
#   'Key': 934,
#   'Character': 'RED LEADER',
#   'Dialog': 'Keep your eyes open for those fighters!'},
#  {'Movie': 'Episode IV',
#   'Key': 935,
#   'Character': 'RED TEN',
#   'Dialog': "There's too much interference!"},
#  {'Movie': 'Episode IV',
#   'Key': 936,
#   'Character': 'RED TEN',
#   'Dialog': 'Red Five, can you see them from where you are?'},
#  {'Movie': 'Episode IV',
#   'Key': 937,
#   'Character': 'LUKE',
#   'Dialog': 'No sign of any... wait!'},
#  {'Movie': 'Episode IV',
#   'Key': 938,
#   'Character': 'LUKE',
#   'Dialog': 'Coming in point three five.'},
#  {'Movie': 'Episode IV',
#   'Key': 939,
#   'Character': 'RED TEN',
#   'Dialog': 'I see them.'},
#  {'Movie': 'Episode IV',
#   'Key': 940,
#   'Character': 'RED LEADER',
#   'Dialog': "I'm in range."},
#  {'Movie': 'Episode IV',
#   'Key': 941,
#   'Character': 'RED LEADER',
#   'Dialog': "Target's coming up!"},
#  {'Movie': 'Episode IV',
#   'Key': 942,
#   'Character': 'RED LEADER',
#   'Dialog': 'Just hold them off for a few seconds.'},
#  {'Movie': 'Episode IV',
#   'Key': 943,
#   'Character': 'VADER',
#   'Dialog': 'Close up formation.'},
#  {'Movie': 'Episode IV',
#   'Key': 944,
#   'Character': 'RED LEADER',
#   'Dialog': 'Almost there!'},
#  {'Movie': 'Episode IV',
#   'Key': 945,
#   'Character': 'RED TEN',
#   'Dialog': "You'd better let her loose."},
#  {'Movie': 'Episode IV',
#   'Key': 946,
#   'Character': 'RED LEADER',
#   'Dialog': 'Almost there!'},
#  {'Movie': 'Episode IV',
#   'Key': 947,
#   'Character': 'RED TEN',
#   'Dialog': "I can't hold them!"},
#  {'Movie': 'Episode IV',
#   'Key': 948,
#   'Character': 'RED LEADER',
#   'Dialog': "It's away!"},
#  {'Movie': 'Episode IV',
#   'Key': 949,
#   'Character': 'RED NINE',
#   'Dialog': "It's a hit!"},
#  {'Movie': 'Episode IV',
#   'Key': 950,
#   'Character': 'RED LEADER',
#   'Dialog': 'Negative.'},
#  {'Movie': 'Episode IV',
#   'Key': 951,
#   'Character': 'RED LEADER',
#   'Dialog': "Negative!  It didn't go in, it just impacted on the surface."},
#  {'Movie': 'Episode IV',
#   'Key': 952,
#   'Character': 'LUKE',
#   'Dialog': "Red Leader, we're right above you.  Turn to point..."},
#  {'Movie': 'Episode IV',
#   'Key': 953,
#   'Character': 'LUKE',
#   'Dialog': "... oh-five; we'll cover for you."},
#  {'Movie': 'Episode IV',
#   'Key': 954,
#   'Character': 'RED LEADER',
#   'Dialog': 'Stay there...'},
#  {'Movie': 'Episode IV',
#   'Key': 955,
#   'Character': 'RED LEADER',
#   'Dialog': '... I just lost my starboard engine.'},
#  {'Movie': 'Episode IV',
#   'Key': 956,
#   'Character': 'RED LEADER',
#   'Dialog': 'Get set up for your attack run.'},
#  {'Movie': 'Episode IV',
#   'Key': 957,
#   'Character': 'DEATH STAR INTERCOM VOICE',
#   'Dialog': 'Rebel base, one minute and closing.'},
#  {'Movie': 'Episode IV',
#   'Key': 958,
#   'Character': 'LUKE',
#   'Dialog': "Biggs, Wedge, let's close it up.  We're going in.  We're going in full throttle."},
#  {'Movie': 'Episode IV',
#   'Key': 959,
#   'Character': 'WEDGE',
#   'Dialog': 'Right with you, boss.'},
#  {'Movie': 'Episode IV',
#   'Key': 960,
#   'Character': 'BIGGS',
#   'Dialog': 'Luke, at that speed will you be able to pull out in time?'},
#  {'Movie': 'Episode IV',
#   'Key': 961,
#   'Character': 'LUKE',
#   'Dialog': "It'll be just like Beggar's Canyon back home."},
#  {'Movie': 'Episode IV',
#   'Key': 962,
#   'Character': 'BIGGS',
#   'Dialog': "We'll stay back far enough to cover you."},
#  {'Movie': 'Episode IV',
#   'Key': 963,
#   'Character': 'WEDGE',
#   'Dialog': "My scope shows the tower, but I can't see the exhaust port!  Are you sure the computer can hit it?"},
#  {'Movie': 'Episode IV',
#   'Key': 964,
#   'Character': 'LUKE',
#   'Dialog': 'Watch yourself!  Increase speed full throttle!'},
#  {'Movie': 'Episode IV',
#   'Key': 965,
#   'Character': 'WEDGE',
#   'Dialog': 'What about that tower?'},
#  {'Movie': 'Episode IV',
#   'Key': 966,
#   'Character': 'LUKE',
#   'Dialog': "You worry about those fighters!  I'll worry about the tower!"},
#  {'Movie': 'Episode IV',
#   'Key': 967,
#   'Character': 'LUKE',
#   'Dialog': "Artoo... that, that stabilizer's broken loose again!  See if you can't lock it down!"},
#  {'Movie': 'Episode IV',
#   'Key': 968,
#   'Character': 'WEDGE',
#   'Dialog': "I'm hit!  I can't stay with you."},
#  {'Movie': 'Episode IV',
#   'Key': 969,
#   'Character': 'LUKE',
#   'Dialog': 'Get clear, Wedge.'},
#  {'Movie': 'Episode IV',
#   'Key': 970,
#   'Character': 'LUKE',
#   'Dialog': "You can't do any more good back there!"},
#  {'Movie': 'Episode IV', 'Key': 971, 'Character': 'WEDGE', 'Dialog': 'Sorry!'},
#  {'Movie': 'Episode IV',
#   'Key': 972,
#   'Character': 'VADER',
#   'Dialog': 'Let him go!  Stay on the leader!'},
#  {'Movie': 'Episode IV',
#   'Key': 973,
#   'Character': 'BIGGS',
#   'Dialog': "Hurry, Luke, they're coming in much faster this time. I can't hold them!"},
#  {'Movie': 'Episode IV',
#   'Key': 974,
#   'Character': 'LUKE',
#   'Dialog': 'Artoo, try and increase the power!'},
#  {'Movie': 'Episode IV',
#   'Key': 975,
#   'Character': 'BIGGS',
#   'Dialog': 'Hurry up, Luke!'},
#  {'Movie': 'Episode IV', 'Key': 976, 'Character': 'BIGGS', 'Dialog': 'Wait!'},
#  {'Movie': 'Episode IV',
#   'Key': 977,
#   'Character': 'DEATH STAR INTERCOM VOICE',
#   'Dialog': 'Rebel base, thirty seconds and closing.'},
#  {'Movie': 'Episode IV',
#   'Key': 978,
#   'Character': 'VADER',
#   'Dialog': "I'm on the leader."},
#  {'Movie': 'Episode IV',
#   'Key': 979,
#   'Character': 'THREEPIO',
#   'Dialog': 'Hang on, Artoo!'},
#  {'Movie': 'Episode IV',
#   'Key': 980,
#   'Character': 'BEN',
#   'Dialog': 'Use the Force, Luke.'},
#  {'Movie': 'Episode IV',
#   'Key': 981,
#   'Character': 'BEN',
#   'Dialog': 'Let go, Luke.'},
#  {'Movie': 'Episode IV',
#   'Key': 982,
#   'Character': 'VADER',
#   'Dialog': 'The Force is strong with this one!'},
#  {'Movie': 'Episode IV',
#   'Key': 983,
#   'Character': 'BEN',
#   'Dialog': 'Luke, trust me.'},
#  {'Movie': 'Episode IV',
#   'Key': 984,
#   'Character': 'BASE VOICE',
#   'Dialog': "His computer's off.  Luke, you switched off your targeting computer.  What's wrong?"},
#  {'Movie': 'Episode IV',
#   'Key': 985,
#   'Character': 'LUKE',
#   'Dialog': "Nothing.  I'm all right."},
#  {'Movie': 'Episode IV',
#   'Key': 986,
#   'Character': 'LUKE',
#   'Dialog': "I've lost Artoo!"},
#  {'Movie': 'Episode IV',
#   'Key': 987,
#   'Character': 'MASSASSI INTERCOM VOICE',
#   'Dialog': 'The Death Star has cleared the planet.  The Death Star has cleared the planet.'},
#  {'Movie': 'Episode IV',
#   'Key': 988,
#   'Character': 'DEATH STAR INTERCOM VOICE',
#   'Dialog': 'Rebel base, in range.'},
#  {'Movie': 'Episode IV',
#   'Key': 989,
#   'Character': 'TARKIN',
#   'Dialog': 'You may fire when ready.'},
#  {'Movie': 'Episode IV',
#   'Key': 990,
#   'Character': 'DEATH STAR INTERCOM VOICE',
#   'Dialog': 'Commence primary ignition.'},
#  {'Movie': 'Episode IV',
#   'Key': 991,
#   'Character': 'VADER',
#   'Dialog': 'I have you now.'},
#  {'Movie': 'Episode IV', 'Key': 992, 'Character': 'VADER', 'Dialog': 'What?'},
#  {'Movie': 'Episode IV', 'Key': 993, 'Character': 'HAN', 'Dialog': 'Yahoo!'},
#  {'Movie': 'Episode IV',
#   'Key': 994,
#   'Character': 'WINGMAN',
#   'Dialog': 'Look out!'},
#  {'Movie': 'Episode IV',
#   'Key': 995,
#   'Character': 'HAN',
#   'Dialog': "You're all clear, kid."},
#  {'Movie': 'Episode IV',
#   'Key': 996,
#   'Character': 'HAN',
#   'Dialog': "Now let's blow this thing and go home!"},
#  {'Movie': 'Episode IV',
#   'Key': 997,
#   'Character': 'INTERCOM VOICE',
#   'Dialog': 'Stand by to fire at Rebel base.'},
#  {'Movie': 'Episode IV',
#   'Key': 998,
#   'Character': 'INTERCOM VOICE',
#   'Dialog': 'Standing by.'},
#  {'Movie': 'Episode IV',
#   'Key': 999,
#   'Character': 'HAN',
#   'Dialog': 'Great shot, kid.  That was one in a million.'},
#  {'Movie': 'Episode IV',
#   'Key': 1000,
#   'Character': 'BEN',
#   'Dialog': 'Remember, the Force will be with you... always.'},
#  ...]
